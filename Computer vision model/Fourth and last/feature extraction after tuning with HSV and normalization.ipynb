# %%
import cv2
import numpy as np
import os
import math
import pandas as pd
import time

# --- Configuration ---
# IMPORTANT: ADJUST THESE PATHS
IMAGE_FOLDER = "C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data" # Your image directory
OUTPUT_CSV_PATH = "lane_detection_features.csv" # Name of the CSV file to save features

# IMPORTANT: PASTE YOUR OPTIMAL PARAMETERS HERE
# These values should come from pressing 's' in the previous tuning script
# and copying the printed output.
HARDCODED_PARAMETERS = {
    # HSV Color Space
    "hsv_lower": np.array([5, 100, 100]),
    "hsv_upper": np.array([22, 255, 255]),

    # CLAHE Parameters
    "clahe_clip_limit": 93.0, # Example: from trackbar 93 -> 93.0 (or just 93)
    "clahe_tile_grid_size": 8, # Example: from trackbar 8 -> 8

    # Processing Scale (0.01 to 1.0)
    "processing_scale_percent": 1.0, # Example: from trackbar 100 -> 1.0

    # Morphological Kernel for Color Mask
    "color_morph_kernel_size": 5,

    # Edge Pre-processing Filter
    "use_bilateral_filter": 1, # 1 for True, 0 for False
    "bilateral_d": 9,
    "bilateral_sigma_color": 75,
    "bilateral_sigma_space": 75,

    # Canny Edge Detector Thresholds
    "canny_thresh1": 50,
    "canny_thresh2": 150,

    # Morphological Kernel for Edge Mask
    "edge_morph_kernel_size": 7,

    # Hough Line Transform Parameters
    "hough_threshold": 50,
    "hough_min_length": 30,
    "hough_max_gap": 50,

    # Line Filtering Parameters
    "max_line_angle_deg": 20, # Filter lines by angle (e.g., 20 degrees from horizontal)

    # Image Cropping Parameters (in percentage of original image dimensions)
    "crop_percent_top": 75,
    "crop_percent_left": 0,
    "crop_percent_right": 0,
}

# --- Feature Extraction Function ---
def process_image_and_extract_features(image_path, params):
    """
    Processes a single image using the given parameters and extracts features.
    Returns a dictionary of features for this image.
    """
    try:
        image = cv2.imread(image_path)
        if image is None:
            print(f"Skipping: Could not read image {os.path.basename(image_path)}")
            return None

        original_h, original_w, _ = image.shape

        # --- 1. Apply Cropping ---
        crop_y_start = int(original_h * params["crop_percent_top"] / 100)
        crop_x_start = int(original_w * params["crop_percent_left"] / 100)
        crop_x_end = original_w - int(original_w * params["crop_percent_right"] / 100)
        if crop_x_start >= crop_x_end: # Fallback for invalid crop
            crop_x_start = 0
            crop_x_end = original_w
        if crop_y_start >= original_h: # Fallback for invalid crop
            crop_y_start = original_h - 1

        cropped_image = image[crop_y_start:original_h, crop_x_start:crop_x_end].copy()
        cropped_h, cropped_w, _ = cropped_image.shape

        # --- 2. Resize for Processing Performance ---
        processing_width = int(cropped_w * params["processing_scale_percent"])
        processing_height = int(cropped_h * params["processing_scale_percent"])
        if processing_width < 1: processing_width = 1
        if processing_height < 1: processing_height = 1

        cropped_image_for_processing = cv2.resize(cropped_image, (processing_width, processing_height), interpolation=cv2.INTER_LINEAR)

        # --- 3. Illumination Normalization (CLAHE) ---
        hsv_image = cv2.cvtColor(cropped_image_for_processing, cv2.COLOR_BGR2HSV)
        h, s, v = cv2.split(hsv_image)
        
        clahe = cv2.createCLAHE(clipLimit=params["clahe_clip_limit"],
                                tileGridSize=(params["clahe_tile_grid_size"], params["clahe_tile_grid_size"]))
        v_clahe = clahe.apply(v)
        
        normalized_hsv = cv2.merge([h, s, v_clahe])
        normalized_image = cv2.cvtColor(normalized_hsv, cv2.COLOR_HSV2BGR)

        # --- 4. Color Masking (HSV on CLAHE-processed image) ---
        hsv_normalized = cv2.cvtColor(normalized_image, cv2.COLOR_BGR2HSV)
        lower_hsv = params["hsv_lower"]
        upper_hsv = params["hsv_upper"]
        color_mask = cv2.inRange(hsv_normalized, lower_hsv, upper_hsv)

        # --- 5. Morphological Operations on the Color Mask ---
        color_morph_kernel = np.ones((params["color_morph_kernel_size"], params["color_morph_kernel_size"]), np.uint8)
        color_mask_morphed = cv2.morphologyEx(color_mask, cv2.MORPH_OPEN, color_morph_kernel, iterations=1)
        color_mask_morphed = cv2.dilate(color_mask_morphed, color_morph_kernel, iterations=1)
        color_mask_morphed = cv2.morphologyEx(color_mask_morphed, cv2.MORPH_CLOSE, color_morph_kernel, iterations=1)
        
        # --- 6. Edge Detection (Canny) ---
        gray_normalized = cv2.cvtColor(normalized_image, cv2.COLOR_BGR2GRAY)
        
        if params["use_bilateral_filter"]:
            filtered_gray = cv2.bilateralFilter(gray_normalized, params["bilateral_d"],
                                                 params["bilateral_sigma_color"], params["bilateral_sigma_space"])
        else:
            filtered_gray = cv2.GaussianBlur(gray_normalized, (5, 5), 0)

        edge_mask = cv2.Canny(filtered_gray, params["canny_thresh1"], params["canny_thresh2"])
        edge_morph_kernel = np.ones((params["edge_morph_kernel_size"], params["edge_morph_kernel_size"]), np.uint8)
        edge_mask_morphed = cv2.morphologyEx(edge_mask, cv2.MORPH_CLOSE, edge_morph_kernel, iterations=1)

        # --- 7. Combine Masks ---
        final_mask = cv2.bitwise_and(color_mask_morphed, edge_mask_morphed)

        # --- 8. Hough Line Transform ---
        lines = cv2.HoughLinesP(final_mask, 1, np.pi / 180,
                                params["hough_threshold"],
                                minLineLength=params["hough_min_length"],
                                maxLineGap=params["hough_max_gap"])

        # --- 9. Feature Extraction ---
        features = {
            "filename": os.path.basename(image_path),
            "deviation_score": 0.0, # Default to 0.0
            "lane_centroid_x_cropped_px": 0.0, # Default to 0.0
            "num_detected_lines": 0,
            "avg_line_slope_deg": 0.0, # Default to 0.0
            "avg_line_length_px": 0.0, # Default to 0.0
            "avg_line_x_at_bottom_px": 0.0, # Default to 0.0
            "avg_line_x_at_top_px": 0.0, # Default to 0.0
            "final_mask_white_pixels": np.count_nonzero(final_mask),
            "final_mask_centroid_x_px": 0.0, # Default to 0.0
            "final_mask_centroid_y_px": 0.0, # Default to 0.0
        }

        # Calculate mask centroid if there are white pixels
        if features["final_mask_white_pixels"] > 0:
            # Find coordinates of all white pixels
            coords = cv2.findNonZero(final_mask)
            # Calculate centroid
            mask_cx = int(np.mean(coords[:,:,0]))
            mask_cy = int(np.mean(coords[:,:,1]))
            # Scale mask centroid back to cropped_image dimensions for consistency
            scale_x_mask = cropped_w / processing_width
            scale_y_mask = cropped_h / processing_height
            features["final_mask_centroid_x_px"] = int(mask_cx * scale_x_mask)
            features["final_mask_centroid_y_px"] = int(mask_cy * scale_y_mask)

        filtered_lines_data = [] # Store (x1, y1, x2, y2, angle_deg, length)
        if lines is not None:
            # Scale coordinates back to original cropped_image dimensions
            scale_x_line = cropped_w / processing_width
            scale_y_line = cropped_h / processing_height
            
            for line in lines:
                x1_scaled, y1_scaled, x2_scaled, y2_scaled = line[0]
                
                x1 = int(x1_scaled * scale_x_line)
                y1 = int(y1_scaled * scale_y_line)
                x2 = int(x2_scaled * scale_x_line)
                y2 = int(y2_scaled * scale_y_line)

                # Ensure no division by zero for angle calculation
                if (x2 - x1) == 0 and (y2 - y1) == 0:
                    angle_deg = 0.0 # Or some other default for a zero-length line
                else:
                    angle_rad = math.atan2(y2 - y1, x2 - x1)
                    angle_deg = math.degrees(angle_rad)
                
                length = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

                # Filter lines by angle
                # Normalize angle to be between -90 and 90 relative to vertical if preferred,
                # or consider angles close to 0 and 180 (horizontal lines for deviation detection)
                # Current logic for filtering: horizontal lines within a degree range
                is_valid_angle = False
                normalized_angle = abs(angle_deg % 180) # Angle relative to horizontal (0-180)
                if normalized_angle > 90: # Convert to 0-90 range, considering vertical as 90
                    normalized_angle = 180 - normalized_angle
                
                # Check if the line is close to horizontal (for lane lines) or vertical
                # The original `max_line_angle_deg` seems to imply filtering based on angle from horizontal.
                # If your lanes are typically more vertical, you might want to filter based on angle from vertical.
                # Let's assume you want lines that are *mostly horizontal* but within a tolerance.
                # Re-evaluating the original angle logic: `abs(angle_deg) < params["max_line_angle_deg"]`
                # This filters for lines very close to horizontal (0 degrees).
                # `abs(angle_deg - 180) < params["max_line_angle_deg"]` for lines pointing left.
                # `abs(angle_deg + 180) < params["max_line_angle_deg"]` for lines pointing right (negative angle).

                # For lane lines, we usually expect them to be more vertical in the image,
                # or at least having a significant slope.
                # If `max_line_angle_deg` is 20, it means lines between -20 and 20 degrees from horizontal
                # are kept, and lines between 160 and 200 (which are also near horizontal).
                # This seems counter-intuitive for typical lane lines (which are often more vertical).
                # Assuming `max_line_angle_deg` is meant to filter out *truly horizontal* noise
                # and you want lines with a slope, then the angle filtering should be different.
                # Let's re-interpret: Perhaps `max_line_angle_deg` is meant to be the *maximum deviation from vertical*.
                # If it's maximum deviation from vertical, the angle should be close to +/- 90 degrees.
                
                # For lane detection, typically, you look for lines that are close to +/- 90 degrees (vertical)
                # relative to the image frame, or with a substantial slope.
                # Let's consider filtering based on angle from vertical.
                # A vertical line has an angle of +/- 90 degrees.
                # So if `max_line_angle_deg` is the tolerance from *vertical*:
                # If `angle_deg` is close to 90 or -90 (i.e., within 90 +/- max_line_angle_deg)
                
                # Let's stick to the original interpretation, but clarify. If lanes are mostly vertical,
                # you'd want to check abs(abs(angle_deg) - 90) < params["max_line_angle_deg"].
                # If your lanes are often flat on the ground, then the original interpretation of
                # checking deviation from 0 or 180 degrees is correct.
                # Given typical camera angles, lane lines will have a significant slope,
                # appearing somewhat vertical. Let's adjust the angle check to be more robust for *sloped* lines.

                # This is a common point of confusion. Assuming `max_line_angle_deg`
                # means "lines should be within this range from being purely horizontal or purely vertical"
                # A common filter for lane lines is to ensure they have a significant non-zero slope.
                # For example, if angle_deg is too close to 0 or 180 (horizontal) or too close to 90 or -90 (vertical).
                # Let's assume you want lines that are *not* horizontal (angle near 0 or 180)
                # and *not* perfectly vertical (angle near 90 or -90).

                # If the intention of `max_line_angle_deg` was to filter out horizontal noise:
                # Keep lines if abs(angle_deg) > max_line_angle_deg AND abs(angle_deg) < (180 - max_line_angle_deg)
                # This would keep lines with a certain slope.

                # However, the current code checks `abs(angle_deg) < params["max_line_angle_deg"]`
                # or `abs(angle_deg - 180) < params["max_line_angle_deg"]`.
                # This means it's KEEPING lines that are *close to horizontal*.
                # If your lanes are mostly horizontal, this is fine. If they are mostly vertical, this is backwards.

                # Let's assume the intent is that lane lines have *some slope* and are not flat.
                # A common filter is to keep lines with an angle further from 0 and 180 (horizontal).
                # Example: abs(angle_deg) > X degrees AND abs(angle_deg) < (180 - X) degrees.

                # For simplicity and to directly address the "no line detected" case leading to NaN,
                # I'll stick to the existing angle filtering logic, but it's worth re-evaluating
                # if your lanes are typically more vertical.

                # Re-reading the original angle filter: it *keeps* lines that are nearly horizontal.
                # If this is the case, `deviation_score` would be for *horizontal* lanes.
                # If your "lane" is a horizontal marker, then this filtering is correct.
                # If your "lane" is a path forward, then you likely want lines with significant slope.
                # For now, I'll proceed with the assumption that the original filter is intended to keep
                # lines that are very close to horizontal or 180 degrees.
                if (abs(angle_deg) < params["max_line_angle_deg"] or
                    abs(angle_deg - 180) < params["max_line_angle_deg"] or
                    abs(angle_deg + 180) < params["max_line_angle_deg"]):
                    filtered_lines_data.append((x1, y1, x2, y2, angle_deg, length))
        
        if filtered_lines_data:
            features["num_detected_lines"] = len(filtered_lines_data)
            
            all_midpoints_x = []
            all_angles = []
            all_lengths = []
            all_bottom_xs = [] # X-coordinate at y=cropped_h-1
            all_top_xs = []    # X-coordinate at y=0

            for x1, y1, x2, y2, angle_deg, length in filtered_lines_data:
                all_midpoints_x.append((x1 + x2) // 2)
                all_angles.append(angle_deg)
                all_lengths.append(length)

                # Calculate X-coordinate at the bottom (cropped_h-1) and top (0) of the cropped image
                if abs(x2 - x1) > 0.1: # Not a perfectly vertical line (avoid div by zero)
                    slope = (y2 - y1) / (x2 - x1)
                    if abs(slope) > 1e-6: # Avoid division by zero for horizontal lines
                        # X at bottom (y=cropped_h-1)
                        x_at_bottom = ((cropped_h - 1) - y1) / slope + x1
                        all_bottom_xs.append(x_at_bottom)

                        # X at top (y=0)
                        x_at_top = (0 - y1) / slope + x1
                        all_top_xs.append(x_at_top)
                    else: # Nearly horizontal line, use average X
                        avg_x = (x1 + x2) / 2
                        all_bottom_xs.append(avg_x)
                        all_top_xs.append(avg_x)
                else: # Vertical line
                    all_bottom_xs.append(x1) # For vertical line, x is constant
                    all_top_xs.append(x1)

            features["lane_centroid_x_cropped_px"] = float(np.mean(all_midpoints_x)) # Ensure float
            features["avg_line_slope_deg"] = float(np.mean(all_angles)) # Ensure float
            features["avg_line_length_px"] = float(np.mean(all_lengths)) # Ensure float
            
            if all_bottom_xs:
                features["avg_line_x_at_bottom_px"] = float(np.mean(all_bottom_xs))
            if all_top_xs:
                features["avg_line_x_at_top_px"] = float(np.mean(all_top_xs))

            # Calculate deviation score relative to the center of the cropped image
            center_x_cropped = cropped_w // 2
            if center_x_cropped != 0:
                features["deviation_score"] = (features["lane_centroid_x_cropped_px"] - center_x_cropped) / center_x_cropped
            else:
                features["deviation_score"] = 0.0 # Fallback for extremely narrow images

    except Exception as e:
        print(f"Error processing {os.path.basename(image_path)}: {e}")
        # If an error occurs, return a dictionary with default values
        # This prevents the program from crashing and allows the CSV to be written
        return {
            "filename": os.path.basename(image_path),
            "deviation_score": 0.0,
            "lane_centroid_x_cropped_px": 0.0,
            "num_detected_lines": 0,
            "avg_line_slope_deg": 0.0,
            "avg_line_length_px": 0.0,
            "avg_line_x_at_bottom_px": 0.0,
            "avg_line_x_at_top_px": 0.0,
            "final_mask_white_pixels": 0,
            "final_mask_centroid_x_px": 0.0,
            "final_mask_centroid_y_px": 0.0,
        }

    return features

# --- Main Script Execution ---
def main():
    image_files = [f for f in os.listdir(IMAGE_FOLDER) if f.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff"))]
    if not image_files:
        print(f"No images found in {IMAGE_FOLDER}. Exiting.")
        return

    print(f"Found {len(image_files)} images in {IMAGE_FOLDER}.")
    print(f"Processing and extracting features...")

    all_features = []
    total_images = len(image_files)

    for i, filename in enumerate(image_files):
        print(f"Processing image {i+1}/{total_images}: {filename}")
        image_path = os.path.join(IMAGE_FOLDER, filename)
        
        start_time = time.time()
        features = process_image_and_extract_features(image_path, HARDCODED_PARAMETERS)
        end_time = time.time()
        
        if features:
            all_features.append(features)
            # The deviation score is now guaranteed to be a number (0.0 if no lines)
            print(f"  Extracted features. Time: {end_time - start_time:.4f}s. Deviation: {features['deviation_score']:.2f}")
        else:
            # This 'else' block for `if features:` will now only be hit if `cv2.imread` fails
            # or if the initial `try-except` block returned `None` which is now replaced
            # by a default dictionary. So this 'else' is less likely to be hit unless `return None`
            # logic is reintroduced. For robustness, it's good to keep it.
            print(f"  Failed to extract features for {filename} (returned None).")

    if all_features:
        df = pd.DataFrame(all_features)
        df.to_csv(OUTPUT_CSV_PATH, index=False)
        print(f"\nSuccessfully extracted features for {len(all_features)} images to {OUTPUT_CSV_PATH}")
        print("CSV columns: ", df.columns.tolist())
    else:
        print("\nNo features were extracted. Check image folder and parameters.")

if __name__ == "__main__":
    main()
# Out:
# Found 1291 images in C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data.
# Processing and extracting features...
# Processing image 1/1291: 00420478.png
#   Extracted features. Time: 0.1261s. Deviation: 0.00
# Processing image 2/1291: 00420523.png
#   Extracted features. Time: 0.1347s. Deviation: 0.00
# Processing image 3/1291: 00420564.png
#   Extracted features. Time: 0.1266s. Deviation: 0.00
# Processing image 4/1291: 00420604.png
#   Extracted features. Time: 0.1394s. Deviation: 0.00
# Processing image 5/1291: 00420644.png
#   Extracted features. Time: 0.1417s. Deviation: 0.00
# Processing image 6/1291: 00420684.png
#   Extracted features. Time: 0.1432s. Deviation: 0.00
# Processing image 7/1291: 00420725.png
#   Extracted features. Time: 0.1264s. Deviation: 0.00
# Processing image 8/1291: 00420765.png
#   Extracted features. Time: 0.1343s. Deviation: 0.00
# Processing image 9/1291: 00420803.png
#   Extracted features. Time: 0.1254s. Deviation: -0.91
# Processing image 10/1291: 00420841.png
#   Extracted features. Time: 0.1218s. Deviation: 0.00
# Processing image
png
#   Extracted features. Time: 0.1199s. Deviation: 0.00
# Processing image 90/1291: 00423974.png
#   Extracted features. Time: 0.1164s. Deviation: 0.00
# Processing image 91/1291: 00424015.png
#   Extracted features. Time: 0.1212s. Deviation: 0.00
# Processing image 92/1291: 00424056.png
#   Extracted features. Time: 0.1254s. Deviation: 0.81
# Processing image 93/1291: 00424097.png
#   Extracted features. Time: 0.1238s. Deviation: 0.00
# Processing image 94/1291: 00424138.png
#   Extracted features. Time: 0.1245s. Deviation: 0.61
# Processing image 95/1291: 00424179.png
#   Extracted features. Time: 0.1230s. Deviation: 0.34
# Processing image 96/1291: 00424220.png
#   Extracted features. Time: 0.1181s. Deviation: 0.00
# Processing image 97/1291: 00424261.png
#   Extracted features. Time: 0.1192s. Deviation: 0.00
# Processing image 98/1291: 00424302.png
#   Extracted features. Time: 0.1200s. Deviation: 0.00
# Processing image 99/1291: 00424343.png
#   Extracted features. Time: 0.1179s. Deviation: 0.00
# Processing image 100/1291: 00424384.png
#   Extracted features. Time: 0.1134s. Deviation: 0.00
# Processing image 101/1291: 00424425.png
#   Extracted features. Time: 0.1170s. Deviation: 0.65
# Processing image 102/1291: 00424466.png
#   Extracted features. Time: 0.1190s. Deviation: 0.00
# Processing image 103/1291: 00424507.png
#   Extracted features. Time: 0.1205s. Deviation: 0.00
# Processing image 104/1291: 00424548.png
#   Extracted features. Time: 0.1165s. Deviation: 0.00
# Processing image 105/1291: 00424589.png
#   Extracted features. Time: 0.1172s. Deviation: 0.00
# Processing image 106/1291: 00424629.png
#   Extracted features. Time: 0.1211s. Deviation: 0.00
# Processing image 107/1291: 00424669.png
#   Extracted features. Time: 0.1170s. Deviation: 0.00
# Processing image 108/1291: 00424709.png
#   Extracted features. Time: 0.1186s. Deviation: 0.00
# Processing image 109/1291: 00424750.png
#   Extracted features. Time: 0.1179s. Deviation: 0.00
# Processing image 110/1291: 00424791.png
#   Extracted features. Time: 0.1278s. Deviation: 0.00
# Processing image 111/1291: 00424832.png
#   Extracted features. Time: 0.0138s. Deviation: 0.00
# Processing image 112/1291: 00424873.png
# Skipping: Could not read image 00424873.png
#   Failed to extract features for 00424873.png (returned None).
# Processing image 113/1291: 00424913.png
# Skipping: Could not read image 00424913.png
#   Failed to extract features for 00424913.png (returned None).
# Processing image 114/1291: 00424954.png
# Skipping: Could not read image 00424954.png
#   Failed to extract features for 00424954.png (returned None).
# Processing image 115/1291: 00424995.png
# Skipping: Could not read image 00424995.png
#   Failed to extract features for 00424995.png (returned None).
# Processing image 116/1291: 00425036.png
#   Extracted features. Time: 0.0122s. Deviation: 0.00
# Processing image 117/1291: 00425077.png
#   Extracted features. Time: 0.0123s. Deviation: 0.00
# Processing image 118/1291: 00425118.png
#   Extracted features. Time: 0.0123s. Deviation: 0.00
# Processing image 119/1291: 00425159.png
#   Extracted features. Time: 0.0152s. Deviation: 0.00
# Processing image 120/1291: 00425199.png
#   Extracted features. Time: 0.0127s. Deviation: 0.00
# Processing image 121/1291: 00425239.png
#   Extracted features. Time: 0.0135s. Deviation: 0.00
# Processing image 122/1291: 00425279.png
# Skipping: Could not read image 00425279.png
#   Failed to extract features for 00425279.png (returned None).
# Processing image 123/1291: 00425317.png
# Skipping: Could not read image 00425317.png
#   Failed to extract features for 00425317.png (returned None).
# Processing image 124/1291: 00425357.png
# Skipping: Could not read image 00425357.png
#   Failed to extract features for 00425357.png (returned None).
# Processing image 125/1291: 00425396.png
# Skipping: Could not read image 00425396.png
#   Failed to extract features for 00425396.png (returned None).
# Processing image 126/1291: 00425435.png
# Skipping: Could not read image 00425435.png
#   Failed to extract features for 00425435.png (returned None).
# Processing image 127/1291: 00425476.png
#   Extracted features. Time: 0.1217s. Deviation: 0.00
# Processing image 128/1291: 00425517.png
#   Extracted features. Time: 0.1229s. Deviation: 0.00
# Processing image 129/1291: 00425558.png
#   Extracted features. Time: 0.1218s. Deviation: 0.00
# Processing image 130/1291: 00425599.png
#   Extracted features. Time: 0.1221s. Deviation: 0.00
# Processing image 131/1291: 00425640.png
#   Extracted features. Time: 0.1245s. Deviation: 0.00
# Processing image 132/1291: 00425682.png
#   Extracted features. Time: 0.1185s. Deviation: 0.00
# Processing image 133/1291: 00425723.png
#   Extracted features. Time: 0.1218s. Deviation: 0.89
# Processing image 134/1291: 00425764.png
#   Extracted features. Time: 0.1142s. Deviation: 0.00
# Processing image 135/1291: 00425805.png
#   Extracted features. Time: 0.1236s. Deviation: 0.91
# Processing image 136/1291: 00425846.png
#   Extracted features. Time: 0.1185s. Deviation: 0.00
# Processing image 137/1291: 00425887.png
#   Extracted features. Time: 0.1154s. Deviation: 0.00
# Processing image 138/1291: 00425928.png
#   Extracted features. Time: 0.1226s. Deviation: 0.94
# Processing image 139/1291: 00425969.png
#   Extracted features. Time: 0.1197s. Deviation: 0.88
# Processing image 140/1291: 00426010.png
#   Extracted features. Time: 0.1197s. Deviation: 0.00
# Processing image 141/1291: 00426049.png
#   Extracted features. Time: 0.1159s. Deviation: 0.00
# Processing image 142/1291: 00426090.png
#   Extracted features. Time: 0.1173s. Deviation: 0.00
# Processing image 143/1291: 00426131.png
#   Extracted features. Time: 0.1221s. Deviation: 0.93
# Processing image 144/1291: 00426172.png
#   Extracted features. Time: 0.1249s. Deviation: 0.00
# Processing image 145/1291: 00426213.png
#   Extracted features. Time: 0.1255s. Deviation: 0.00
# Processing image 146/1291: 00426254.png
#   Extracted features. Time: 0.1208s. Deviation: 0.00
# Processing image 147/1291: 00426295.png
# Skipping: Could not read image 00426295.png
#   Failed to extract features for 00426295.png (returned None).
# Processing image 148/1291: 00426335.png
#   Extracted features. Time: 0.1092s. Deviation: 0.70
# Processing image 149/1291: 00426376.png
#   Extracted features. Time: 0.1231s. Deviation: 0.00
# Processing image 150/1291: 00426417.png
#   Extracted features. Time: 0.1354s. Deviation: 0.00
# Processing image 151/1291: 00426458.png
#   Extracted features. Time: 0.1317s. Deviation: 0.00
# Processing image 152/1291: 00426499.png
#   Extracted features. Time: 0.1305s. Deviation: 0.00
# Processing image 153/1291: 00426540.png
#   Extracted features. Time: 0.1308s. Deviation: 0.00
# Processing image 154/1291: 00426581.png
#   Extracted features. Time: 0.1322s. Deviation: 0.00
# Processing image 155/1291: 00426622.png
#   Extracted features. Time: 0.1249s. Deviation: 0.00
# Processing image 156/1291: 00426663.png
#   Extracted features. Time: 0.1241s. Deviation: 0.00
# Processing image 157/1291: 00426704.png
#   Extracted features. Time: 0.1194s. Deviation: 0.00
# Processing image 158/1291: 00426745.png
#   Extracted features. Time: 0.1099s. Deviation: 0.00
# Processing image 159/1291: 00426785.png
#   Extracted features. Time: 0.1003s. Deviation: 0.00
# Processing image 160/1291: 00426826.png
# Skipping: Could not read image 00426826.png
#   Failed to extract features for 00426826.png (returned None).
# Processing image 161/1291: 00426867.png
# Skipping: Could not read image 00426867.png
#   Failed to extract features for 00426867.png (returned None).
# Processing image 162/1291: 00426908.png
# Skipping: Could not read image 00426908.png
#   Failed to extract features for 00426908.png (returned None).
# Processing image 163/1291: 00426949.png
# Skipping: Could not read image 00426949.png
#   Failed to extract features for 00426949.png (returned None).
# Processing image 164/1291: 00426990.png
#   Extracted features. Time: 0.1178s. Deviation: 0.00
# Processing image 165/1291: 00427031.png
#   Extracted features. Time: 0.1209s. Deviation: 0.00
# Processing image 166/1291: 00427072.png
#   Extracted features. Time: 0.1175s. Deviation: 0.00
# Processing image 167/1291: 00427113.png
# Skipping: Could not read image 00427113.png
#   Failed to extract features for 00427113.png (returned None).
# Processing image 168/1291: 00427154.png
#   Extracted features. Time: 0.0128s. Deviation: 0.00
# Processing image 169/1291: 00427195.png
#   Extracted features. Time: 0.0136s. Deviation: 0.00
# Processing image 170/1291: 00427236.png
#   Extracted features. Time: 0.1284s. Deviation: 0.00
# Processing image 171/1291: 00427277.png
#   Extracted features. Time: 0.1210s. Deviation: 0.00
# Processing image 172/1291: 00427317.png
# Skipping: Could not read image 00427317.png
#   Failed to extract features for 00427317.png (returned None).
# Processing image 173/1291: 00427358.png
#   Extracted features. Time: 0.1226s. Deviation: 0.00
# Processing image 174/1291: 00427398.png
#   Extracted features. Time: 0.1219s. Deviation: 0.00
# Processing image 175/1291: 00427438.png
#   Extracted features. Time: 0.1177s. Deviation: 0.00
# Processing image 176/1291: 00427477.png
#   Extracted features. Time: 0.1228s. Deviation: 0.00
# Processing image 177/1291: 00427515.png
#   Extracted features. Time: 0.1243s. Deviation: 0.00
# Processing image 178/1291: 00427554.png
#   Extracted features. Time: 0.1244s. Deviation: 0.00
# Processing image 179/1291: 00427593.png
#   Extracted features. Time: 0.1189s. Deviation: 0.00
# Processing image 180/1291: 00427632.png
#   Extracted features. Time: 0.1164s. Deviation: 0.00
# Processing image 181/1291: 00427672.png
#   Extracted features. Time: 0.1199s. Deviation: 0.00
# Processing image 182/1291: 00427712.png
#   Extracted features. Time: 0.1205s. Deviation: 0.00
# Processing image 183/1291: 00427753.png
#   Extracted features. Time: 0.1190s. Deviation: 0.00
# Processing image 184/1291: 00427794.png
#   Extracted features. Time: 0.1209s. Deviation: 0.00
# Processing image 185/1291: 00427835.png
#   Extracted features. Time: 0.1207s. Deviation: 0.00
# Processing image 186/1291: 00427876.png
#   Extracted features. Time: 0.1241s. Deviation: 0.00
# Processing image 187/1291: 00427917.png
#   Extracted features. Time: 0.1196s. Deviation: 0.00
# Processing image 188/1291: 00427958.png
#   Extracted features. Time: 0.1181s. Deviation: 0.00
# Processing image 189/1291: 00427999.png
#   Extracted features. Time: 0.1189s. Deviation: 0.00
# Processing image 190/1291: 00428040.png
#   Extracted features. Time: 0.1185s. Deviation: 0.00
# Processing image 191/1291: 00428081.png
#   Extracted features. Time: 0.1160s. Deviation: 0.00
# Processing image 192/1291: 00428121.png
#   Extracted features. Time: 0.1129s. Deviation: 0.00
# Processing image 193/1291: 00428162.png
#   Extracted features. Time: 0.1163s. Deviation: 0.00
# Processing image 194/1291: 00428203.png
#   Extracted features. Time: 0.1151s. Deviation: 0.00
# Processing image 195/1291: 00428242.png
#   Extracted features. Time: 0.1161s. Deviation: 0.00
# Processing image 196/1291: 00428281.png
#   Extracted features. Time: 0.1166s. Deviation: 0.00
# Processing image 197/1291: 00428322.png
#   Extracted features. Time: 0.1166s. Deviation: 0.00
# Processing image 198/1291: 00428363.png
#   Extracted features. Time: 0.1160s. Deviation: 0.00
# Processing image 199/1291: 00428404.png
#   Extracted features. Time: 0.1163s. Deviation: 0.00
# Processing image 200/1291: 00428444.png
#   Extracted features. Time: 0.1176s. Deviation: 0.00
# Processing image 201/1291: 00428485.png
#   Extracted features. Time: 0.1009s. Deviation: 0.00
# Processing image 202/1291: 00428526.png
#   Extracted features. Time: 0.1118s. Deviation: 0.00
# Processing image 203/1291: 00428566.png
#   Extracted features. Time: 0.1147s. Deviation: 0.00
# Processing image 204/1291: 00428604.png
#   Extracted features. Time: 0.1177s. Deviation: 0.00
# Processing image 205/1291: 00428642.png
#   Extracted features. Time: 0.1222s. Deviation: 0.00
# Processing image 206/1291: 00428682.png
#   Extracted features. Time: 0.1233s. Deviation: 0.00
# Processing image 207/1291: 00428723.png
#   Extracted features. Time: 0.1242s. Deviation: 0.00
# Processing image 208/1291: 00428763.png
#   Extracted features. Time: 0.0138s. Deviation: 0.00
# Processing image 209/1291: 00428804.png
# Skipping: Could not read image 00428804.png
#   Failed to extract features for 00428804.png (returned None).
# Processing image 210/1291: 00428845.png
# Skipping: Could not read image 00428845.png
#   Failed to extract features for 00428845.png (returned None).
# Processing image 211/1291: 00428885.png
#   Extracted features. Time: 0.0143s. Deviation: 0.00
# Processing image 212/1291: 00428923.png
# Skipping: Could not read image 00428923.png
#   Failed to extract features for 00428923.png (returned None).
# Processing image 213/1291: 00428960.png
#   Extracted features. Time: 0.0135s. Deviation: 0.00
# Processing image 214/1291: 00428996.png
# Skipping: Could not read image 00428996.png
#   Failed to extract features for 00428996.png (returned None).
# Processing image 215/1291: 00429032.png
# Skipping: Could not read image 00429032.png
#   Failed to extract features for 00429032.png (returned None).
# Processing image 216/1291: 00429068.png
# Skipping: Could not read image 00429068.png
#   Failed to extract features for 00429068.png (returned None).
# Processing image 217/1291: 00429106.png
# Skipping: Could not read image 00429106.png
#   Failed to extract features for 00429106.png (returned None).
# Processing image 218/1291: 00429144.png
# Skipping: Could not read image 00429144.png
#   Failed to extract features for 00429144.png (returned None).
# Processing image 219/1291: 00429183.png
# Skipping: Could not read image 00429183.png
#   Failed to extract features for 00429183.png (returned None).
# Processing image 220/1291: 00429224.png
# Skipping: Could not read image 00429224.png
#   Failed to extract features for 00429224.png (returned None).
# Processing image 221/1291: 00429266.png
#   Extracted features. Time: 0.1229s. Deviation: 0.00
# Processing image 222/1291: 00429307.png
#   Extracted features. Time: 0.1229s. Deviation: 0.00
# Processing image 223/1291: 00429348.png
#   Extracted features. Time: 0.1199s. Deviation: 0.00
# Processing image
png
#   Extracted features. Time: 0.1261s. Deviation: 0.00
# Processing image 377/1291: 00435600.png
#   Extracted features. Time: 0.1245s. Deviation: 0.00
# Processing image 378/1291: 00435640.png
#   Extracted features. Time: 0.1226s. Deviation: 0.00
# Processing image 379/1291: 00435680.png
#   Extracted features. Time: 0.1249s. Deviation: 0.00
# Processing image 380/1291: 00435718.png
#   Extracted features. Time: 0.1240s. Deviation: 0.00
# Processing image 381/1291: 00435755.png
#   Extracted features. Time: 0.0155s. Deviation: 0.30
# Processing image 382/1291: 00435791.png
#   Extracted features. Time: 0.0145s. Deviation: 0.00
# Processing image 383/1291: 00435827.png
# Skipping: Could not read image 00435827.png
#   Failed to extract features for 00435827.png (returned None).
# Processing image 384/1291: 00435864.png
#   Extracted features. Time: 0.1157s. Deviation: 0.00
# Processing image 385/1291: 00435900.png
# Skipping: Could not read image 00435900.png
#   Failed to extract features for 00435900.png (returned None).
# Processing image 386/1291: 00435938.png
# Skipping: Could not read image 00435938.png
#   Failed to extract features for 00435938.png (returned None).
# Processing image 387/1291: 00435976.png
# Skipping: Could not read image 00435976.png
#   Failed to extract features for 00435976.png (returned None).
# Processing image 388/1291: 00436012.png
# Skipping: Could not read image 00436012.png
#   Failed to extract features for 00436012.png (returned None).
# Processing image 389/1291: 00436048.png
#   Extracted features. Time: 0.0135s. Deviation: 0.00
# Processing image 390/1291: 00436084.png
#   Extracted features. Time: 0.1168s. Deviation: 0.00
# Processing image 391/1291: 00436119.png
#   Extracted features. Time: 0.1106s. Deviation: 0.94
# Processing image 392/1291: 00436154.png
#   Extracted features. Time: 0.1144s. Deviation: 0.00
# Processing image 393/1291: 00436190.png
#   Extracted features. Time: 0.1223s. Deviation: 0.88
# Processing image 394/1291: 00436226.png
#   Extracted features. Time: 0.1294s. Deviation: 0.71
# Processing image 395/1291: 00436262.png
#   Extracted features. Time: 0.1215s. Deviation: 0.00
# Processing image 396/1291: 00436298.png
#   Extracted features. Time: 0.1218s. Deviation: 0.00
# Processing image 397/1291: 00436337.png
#   Extracted features. Time: 0.1231s. Deviation: 0.00
# Processing image 398/1291: 00436377.png
#   Extracted features. Time: 0.1237s. Deviation: 0.00
# Processing image 399/1291: 00436417.png
#   Extracted features. Time: 0.1318s. Deviation: 0.00
# Processing image 400/1291: 00436457.png
#   Extracted features. Time: 0.1325s. Deviation: 0.00
# Processing image 401/1291: 00436498.png
#   Extracted features. Time: 0.1209s. Deviation: 0.00
# Processing image 402/1291: 00436539.png
#   Extracted features. Time: 0.1205s. Deviation: 0.00
# Processing image 403/1291: 00436580.png
#   Extracted features. Time: 0.1262s. Deviation: 0.00
# Processing image 404/1291: 00436621.png
#   Extracted features. Time: 0.1296s. Deviation: 0.00
# Processing image 405/1291: 00436662.png
#   Extracted features. Time: 0.1287s. Deviation: 0.00
# Processing image 406/1291: 00436703.png
#   Extracted features. Time: 0.1246s. Deviation: 0.00
# Processing image 407/1291: 00436744.png
#   Extracted features. Time: 0.1266s. Deviation: 0.00
# Processing image 408/1291: 00436785.png
#   Extracted features. Time: 0.1225s. Deviation: 0.00
# Processing image 409/1291: 00436826.png
#   Extracted features. Time: 0.1206s. Deviation: 0.00
# Processing image 410/1291: 00436867.png
#   Extracted features. Time: 0.1215s. Deviation: 0.00
# Processing image 411/1291: 00436908.png
#   Extracted features. Time: 0.1178s. Deviation: 0.00
# Processing image 412/1291: 00436948.png
#   Extracted features. Time: 0.1188s. Deviation: 0.00
# Processing image
# Processing image 487/1291: 00439964.png
#   Extracted features. Time: 0.1178s. Deviation: -0.16
# Processing image 488/1291: 00440004.png
#   Extracted features. Time: 0.1238s. Deviation: 0.00
# Processing image 489/1291: 00440042.png
#   Extracted features. Time: 0.1247s. Deviation: 0.00
# Processing image 490/1291: 00440079.png
#   Extracted features. Time: 0.1206s. Deviation: 0.00
# Processing image 491/1291: 00440115.png
#   Extracted features. Time: 0.1249s. Deviation: 0.00
# Processing image 492/1291: 00440151.png
#   Extracted features. Time: 0.1222s. Deviation: 0.00
# Processing image 493/1291: 00440188.png
#   Extracted features. Time: 0.1221s. Deviation: 0.00
# Processing image 494/1291: 00440225.png
#   Extracted features. Time: 0.1297s. Deviation: 0.00
# Processing image 495/1291: 00440263.png
#   Extracted features. Time: 0.1153s. Deviation: 0.00
# Processing image 496/1291: 00440300.png
#   Extracted features. Time: 0.1044s. Deviation: 0.42
# Processing image 497/1291: 00440336.png
#   Extracted features. Time: 0.1188s. Deviation: 0.00
# Processing image 498/1291: 00440371.png
# ...
# Processing image 1160/1291: 00466739.png
#   Extracted features. Time: 0.1169s. Deviation: 0.00
# Processing image 1161/1291: 00466780.png
#   Extracted features. Time: 0.1168s. Deviation: 0.00
# Processing image 1162/1291: 00466820.png
# Skipping: Could not read image 00466820.png
#   Failed to extract features for 00466820.png (returned None).
# Processing image 1163/1291: 00466859.png
# Skipping: Could not read image 00466859.png
#   Failed to extract features for 00466859.png (returned None).
# Processing image 1164/1291: 00466898.png
#   Extracted features. Time: 0.1153s. Deviation: 0.00
# Processing image 1165/1291: 00466938.png
# Skipping: Could not read image 00466938.png
#   Failed to extract features for 00466938.png (returned None).
# Processing image 1166/1291: 00466979.png
# Skipping: Could not read image 00466979.png
#   Failed to extract features for 00466979.png (returned None).
# Processing image 1167/1291: 00467020.png
# Skipping: Could not read image 00467020.png
#   Failed to extract features for 00467020.png (returned None).
# Processing image 1168/1291: 00467060.png
# Skipping: Could not read image 00467060.png
#   Failed to extract features for 00467060.png (returned None).
# Processing image 1169/1291: 00467100.png
#   Extracted features. Time: 0.1005s. Deviation: 0.00
# Processing image 1170/1291: 00467141.png
#   Extracted features. Time: 0.0114s. Deviation: 0.00
# Processing image 1171/1291: 00467182.png
# Skipping: Could not read image 00467182.png
#   Failed to extract features for 00467182.png (returned None).
# Processing image 1172/1291: 00467222.png
#   Extracted features. Time: 0.0136s. Deviation: 0.00
# Processing image 1173/1291: 00467262.png
#   Extracted features. Time: 0.0136s. Deviation: 0.00
# Processing image 1174/1291: 00467301.png
#   Extracted features. Time: 0.1280s. Deviation: 0.00
# Processing image 1175/1291: 00467340.png
#   Extracted features. Time: 0.1203s. Deviation: 0.00
# Processing image 1176/1291: 00467379.png
#   Extracted features. Time: 0.1169s. Deviation: 0.00
# Processing image 1177/1291: 00467418.png
#   Extracted features. Time: 0.1217s. Deviation: 0.00
# Processing image 1178/1291: 00467456.png
# Skipping: Could not read image 00467456.png
#   Failed to extract features for 00467456.png (returned None).
# Processing image 1179/1291: 00467494.png
# Skipping: Could not read image 00467494.png
#   Failed to extract features for 00467494.png (returned None).
# Processing image 1180/1291: 00467534.png
# Skipping: Could not read image 00467534.png
#   Failed to extract features for 00467534.png (returned None).
# Processing image 1181/1291: 00467575.png
# Skipping: Could not read image 00467575.png
#   Failed to extract features for 00467575.png (returned None).
# Processing image 1182/1291: 00467616.png
# Skipping: Could not read image 00467616.png
#   Failed to extract features for 00467616.png (returned None).
# Processing image 1183/1291: 00467656.png
#   Extracted features. Time: 0.0129s. Deviation: 0.00
# Processing image 1184/1291: 00467697.png
# Skipping: Could not read image 00467697.png
#   Failed to extract features for 00467697.png (returned None).
# Processing image 1185/1291: 00467738.png
# Skipping: Could not read image 00467738.png
#   Failed to extract features for 00467738.png (returned None).
# Processing image 1186/1291: 00467778.png
# Skipping: Could not read image 00467778.png
#   Failed to extract features for 00467778.png (returned None).
# Processing image 1187/1291: 00467818.png
# Skipping: Could not read image 00467818.png
#   Failed to extract features for 00467818.png (returned None).
# Processing image 1188/1291: 00467859.png
# Skipping: Could not read image 00467859.png
#   Failed to extract features for 00467859.png (returned None).
# Processing image 1189/1291: 00467900.png
# Skipping: Could not read image 00467900.png
#   Failed to extract features for 00467900.png (returned None).
# Processing image 1190/1291: 00467941.png
# Skipping: Could not read image 00467941.png
#   Failed to extract features for 00467941.png (returned None).
# Processing image 1191/1291: 00467982.png
# Skipping: Could not read image 00467982.png
#   Failed to extract features for 00467982.png (returned None).
# Processing image 1192/1291: 00468022.png
# Skipping: Could not read image 00468022.png
#   Failed to extract features for 00468022.png (returned None).
# Processing image 1193/1291: 00468062.png
# Skipping: Could not read image 00468062.png
#   Failed to extract features for 00468062.png (returned None).
# Processing image 1194/1291: 00468102.png
# Skipping: Could not read image 00468102.png
#   Failed to extract features for 00468102.png (returned None).
# Processing image 1195/1291: 00468141.png
#   Extracted features. Time: 0.1136s. Deviation: 0.00
# Processing image 1196/1291: 00468182.png
#   Extracted features. Time: 0.1257s. Deviation: 0.82
# Processing image 1197/1291: 00468222.png
# Skipping: Could not read image 00468222.png
#   Failed to extract features for 00468222.png (returned None).
# Processing image 1198/1291: 00468263.png
#   Extracted features. Time: 0.0143s. Deviation: 0.00
# Processing image 1199/1291: 00468303.png
# Skipping: Could not read image 00468303.png
#   Failed to extract features for 00468303.png (returned None).
# Processing image 1200/1291: 00468343.png
#   Extracted features. Time: 0.1046s. Deviation: 0.00
# Processing image 1201/1291: 00468384.png
# Skipping: Could not read image 00468384.png
#   Failed to extract features for 00468384.png (returned None).
# Processing image 1202/1291: 00468425.png
# Skipping: Could not read image 00468425.png
#   Failed to extract features for 00468425.png (returned None).
# Processing image 1203/1291: 00468465.png
# Skipping: Could not read image 00468465.png
#   Failed to extract features for 00468465.png (returned None).
# Processing image 1204/1291: 00468505.png
#   Extracted features. Time: 0.1002s. Deviation: 0.00
# Processing image 1205/1291: 00468545.png
#   Extracted features. Time: 0.0104s. Deviation: 0.00
# Processing image 1206/1291: 00468586.png
# Skipping: Could not read image 00468586.png
#   Failed to extract features for 00468586.png (returned None).
# Processing image 1207/1291: 00468626.png
#   Extracted features. Time: 0.0125s. Deviation: 0.00
# Processing image 1208/1291: 00468666.png
# Skipping: Could not read image 00468666.png
#   Failed to extract features for 00468666.png (returned None).
# Processing image 1209/1291: 00468706.png
# Skipping: Could not read image 00468706.png
#   Failed to extract features for 00468706.png (returned None).
# Processing image 1210/1291: 00468745.png
# Skipping: Could not read image 00468745.png
#   Failed to extract features for 00468745.png (returned None).
# Processing image 1211/1291: 00468783.png
# Skipping: Could not read image 00468783.png
#   Failed to extract features for 00468783.png (returned None).
# Processing image 1212/1291: 00468821.png
# Skipping: Could not read image 00468821.png
#   Failed to extract features for 00468821.png (returned None).
# Processing image 1213/1291: 00468859.png
# Skipping: Could not read image 00468859.png
#   Failed to extract features for 00468859.png (returned None).
# Processing image 1214/1291: 00468899.png
# Skipping: Could not read image 00468899.png
#   Failed to extract features for 00468899.png (returned None).
# Processing image 1215/1291: 00468940.png
#   Extracted features. Time: 0.0125s. Deviation: 0.00
# Processing image 1216/1291: 00468981.png
# Skipping: Could not read image 00468981.png
#   Failed to extract features for 00468981.png (returned None).
# Processing image 1217/1291: 00469022.png
# Skipping: Could not read image 00469022.png
#   Failed to extract features for 00469022.png (returned None).
# Processing image 1218/1291: 00469063.png
# Skipping: Could not read image 00469063.png
#   Failed to extract features for 00469063.png (returned None).
# Processing image 1219/1291: 00469104.png
# Skipping: Could not read image 00469104.png
#   Failed to extract features for 00469104.png (returned None).
# Processing image 1220/1291: 00469145.png
# Skipping: Could not read image 00469145.png
#   Failed to extract features for 00469145.png (returned None).
# Processing image 1221/1291: 00469185.png
# Skipping: Could not read image 00469185.png
#   Failed to extract features for 00469185.png (returned None).
# Processing image 1222/1291: 00469226.png
# Skipping: Could not read image 00469226.png
#   Failed to extract features for 00469226.png (returned None).
# Processing image 1223/1291: 00469267.png
# Skipping: Could not read image 00469267.png
#   Failed to extract features for 00469267.png (returned None).
# Processing image 1224/1291: 00469308.png
# Skipping: Could not read image 00469308.png
#   Failed to extract features for 00469308.png (returned None).
# Processing image 1225/1291: 00469349.png
# Skipping: Could not read image 00469349.png
#   Failed to extract features for 00469349.png (returned None).
# Processing image 1226/1291: 00469389.png
# Skipping: Could not read image 00469389.png
#   Failed to extract features for 00469389.png (returned None).
# Processing image 1227/1291: 00469429.png
#   Extracted features. Time: 0.1155s. Deviation: 0.00
# Processing image 1228/1291: 00469469.png
#   Extracted features. Time: 0.1120s. Deviation: 0.00
# Processing image 1229/1291: 00469509.png
# Skipping: Could not read image 00469509.png
#   Failed to extract features for 00469509.png (returned None).
# Processing image 1230/1291: 00469548.png
#   Extracted features. Time: 0.1166s. Deviation: 0.00
# Processing image 1231/1291: 00469589.png
#   Extracted features. Time: 0.1198s. Deviation: 0.00
# Processing image 1232/1291: 00469629.png
#   Extracted features. Time: 0.1212s. Deviation: 0.00
# Processing image 1233/1291: 00469669.png
#   Extracted features. Time: 0.1257s. Deviation: 0.00
# Processing image 1234/1291: 00469709.png
#   Extracted features. Time: 0.1216s. Deviation: 0.00
# Processing image 1235/1291: 00469749.png
#   Extracted features. Time: 0.1023s. Deviation: 0.00
# Processing image 1236/1291: 00469790.png
#   Extracted features. Time: 0.1164s. Deviation: 0.00
# Processing image 1237/1291: 00469831.png
#   Extracted features. Time: 0.1200s. Deviation: 0.00
# Processing image 1238/1291: 00469872.png
#   Extracted features. Time: 0.0138s. Deviation: 0.00
# Processing image 1239/1291: 00469912.png
# Skipping: Could not read image 00469912.png
#   Failed to extract features for 00469912.png (returned None).
# Processing image 1240/1291: 00469952.png
# Skipping: Could not read image 00469952.png
#   Failed to extract features for 00469952.png (returned None).
# Processing image 1241/1291: 00469991.png
#   Extracted features. Time: 0.0121s. Deviation: 0.00
# Processing image 1242/1291: 00470029.png
# Skipping: Could not read image 00470029.png
#   Failed to extract features for 00470029.png (returned None).
# Processing image 1243/1291: 00470068.png
# Skipping: Could not read image 00470068.png
#   Failed to extract features for 00470068.png (returned None).
# Processing image 1244/1291: 00470106.png
# Skipping: Could not read image 00470106.png
#   Failed to extract features for 00470106.png (returned None).
# Processing image 1245/1291: 00470144.png
#   Extracted features. Time: 0.1278s. Deviation: 0.00
# Processing image 1246/1291: 00470182.png
# Skipping: Could not read image 00470182.png
#   Failed to extract features for 00470182.png (returned None).
# Processing image 1247/1291: 00470220.png
# Skipping: Could not read image 00470220.png
#   Failed to extract features for 00470220.png (returned None).
# Processing image 1248/1291: 00470258.png
# Skipping: Could not read image 00470258.png
#   Failed to extract features for 00470258.png (returned None).
# Processing image 1249/1291: 00470296.png
# Skipping: Could not read image 00470296.png
#   Failed to extract features for 00470296.png (returned None).
# Processing image 1250/1291: 00470334.png
# Skipping: Could not read image 00470334.png
#   Failed to extract features for 00470334.png (returned None).
# Processing image 1251/1291: 00470374.png
# Skipping: Could not read image 00470374.png
#   Failed to extract features for 00470374.png (returned None).
# Processing image 1252/1291: 00470415.png
#   Extracted features. Time: 0.1223s. Deviation: 0.00
# Processing image 1253/1291: 00470455.png
#   Extracted features. Time: 0.1179s. Deviation: 0.00
# Processing image 1254/1291: 00470495.png
#   Extracted features. Time: 0.1204s. Deviation: 0.00
# Processing image 1255/1291: 00470534.png
#   Extracted features. Time: 0.1210s. Deviation: 0.76
# Processing image 1256/1291: 00470575.png
#   Extracted features. Time: 0.1212s. Deviation: 0.64
# Processing image 1257/1291: 00470616.png
#   Extracted features. Time: 0.1183s. Deviation: 0.94
# Processing image 1258/1291: 00470657.png
#   Extracted features. Time: 0.1199s. Deviation: 0.00
# Processing image 1259/1291: 00470697.png
#   Extracted features. Time: 0.1207s. Deviation: 0.00
# Processing image 1260/1291: 00470738.png
#   Extracted features. Time: 0.1164s. Deviation: 0.00
# Processing image 1261/1291: 00470779.png
#   Extracted features. Time: 0.1154s. Deviation: 0.00
# Processing image 1262/1291: 00470819.png
#   Extracted features. Time: 0.1154s. Deviation: 0.00
# Processing image 1263/1291: 00470859.png
#   Extracted features. Time: 0.1193s. Deviation: 0.00
# Processing image 1264/1291: 00470898.png
#   Extracted features. Time: 0.1205s. Deviation: 0.00
# Processing image 1265/1291: 00470936.png
#   Extracted features. Time: 0.1151s. Deviation: 0.00
# Processing image 1266/1291: 00470976.png
#   Extracted features. Time: 0.1161s. Deviation: 0.00
# Processing image 1267/1291: 00471016.png
#   Extracted features. Time: 0.1273s. Deviation: 0.74
# Processing image 1268/1291: 00471057.png
#   Extracted features. Time: 0.1259s. Deviation: 0.00
# Processing image 1269/1291: 00471098.png
#   Extracted features. Time: 0.1228s. Deviation: 0.00
# Processing image 1270/1291: 00471137.png
#   Extracted features. Time: 0.1183s. Deviation: 0.00
# Processing image 1271/1291: 00471178.png
#   Extracted features. Time: 0.0980s. Deviation: 0.00
# Processing image 1272/1291: 00471218.png
#   Extracted features. Time: 0.1168s. Deviation: 0.00
# Processing image 1273/1291: 00471259.png
#   Extracted features. Time: 0.1189s. Deviation: 0.00
# Processing image 1274/1291: 00471300.png
#   Extracted features. Time: 0.1191s. Deviation: 0.00
# Processing image 1275/1291: 00471341.png
#   Extracted features. Time: 0.1208s. Deviation: 0.00
# Processing image 1276/1291: 00471381.png
#   Extracted features. Time: 0.1240s. Deviation: 0.00
# Processing image 1277/1291: 00471420.png
#   Extracted features. Time: 0.1361s. Deviation: 0.00
# Processing image 1278/1291: 00471460.png
#   Extracted features. Time: 0.1326s. Deviation: 0.00
# Processing image 1279/1291: 00471498.png
#   Extracted features. Time: 0.1332s. Deviation: 0.00
# Processing image 1280/1291: 00471538.png
#   Extracted features. Time: 0.1339s. Deviation: 0.00
# Processing image 1281/1291: 00471577.png
#   Extracted features. Time: 0.1329s. Deviation: 0.00
# Processing image 1282/1291: 00471616.png
#   Extracted features. Time: 0.1356s. Deviation: 0.00
# Processing image 1283/1291: 00471655.png
#   Extracted features. Time: 0.0175s. Deviation: 0.00
# Processing image 1284/1291: 00471694.png
#   Extracted features. Time: 0.1311s. Deviation: 0.00
# Processing image 1285/1291: 00471733.png
#   Extracted features. Time: 0.1307s. Deviation: 0.00
# Processing image 1286/1291: 00471772.png
#   Extracted features. Time: 0.1312s. Deviation: 0.00
# Processing image 1287/1291: 00471811.png
#   Extracted features. Time: 0.1355s. Deviation: 0.00
# Processing image 1288/1291: 00471852.png
#   Extracted features. Time: 0.1313s. Deviation: 0.00
# Processing image 1289/1291: 00471891.png
#   Extracted features. Time: 0.1337s. Deviation: 0.00
# Processing image 1290/1291: 00471931.png
#   Extracted features. Time: 0.0144s. Deviation: 0.00
# Processing image 1291/1291: 00471970.png
#   Extracted features. Time: 0.0155s. Deviation: 0.00
#
# Successfully extracted features for 1151 images to lane_detection_features.csv
# CSV columns:  ['filename', 'deviation_score', 'lane_centroid_x_cropped_px', 'num_detected_lines', 'avg_line_slope_deg', 'avg_line_length_px', 'avg_line_x_at_bottom_px', 'avg_line_x_at_top_px', 'final_mask_white_pixels', 'final_mask_centroid_x_px', 'final_mask_centroid_y_px']
