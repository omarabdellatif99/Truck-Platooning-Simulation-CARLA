# %%
import cv2
import numpy as np
import os
import math # For angle calculations
import time # For performance timing

# --- Configuration ---
# IMPORTANT: ADJUST THIS PATH to the folder containing your Carla environment images.
# Example: "C:/Users/YourUser/Documents/CarlaImages"
image_folder = "C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data" # <<< Adjust this path

# Supported image file extensions
image_files = [f for f in os.listdir(image_folder) if f.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff"))]

print(f"Loaded {len(image_files)} images.")
if len(image_files) == 0:
    print("ERROR: No images found. Please check your 'image_folder' path or file extensions.")
    exit()

current_index = 0 # Start with the first image

# --- Create Tuning Window and Trackbars ---
cv2.namedWindow("Tuning", cv2.WINDOW_NORMAL)
# Set initial window size. You might need to maximize it manually for all views.
cv2.resizeWindow("Tuning", 1920, 1080)

print("\n--- Tuning Guide ---")
print("This version uses CLAHE (Contrast Limited Adaptive Histogram Equalization) for illumination normalization.")
print("The image is scaled down for processing to improve performance.")
print("First, focus on 'CLAHE Clip Limit' and 'CLAHE Tile Grid Size' to normalize image brightness.")
print("Then, adjust 'H_Lower', 'H_Upper', 'S_Lower', 'S_Upper', 'V_Lower', 'V_Upper' on the *CLAHE-processed* image.")
print("Observe 'CLAHE Processed Image', 'Color Mask (CLAHE+HSV)', and 'Final Mask' carefully.")
print("\n--- Performance Tips (if still laggy): ---")
print("  1. **Crucial:** Adjust 'Processing Scale (%)'. Smaller values mean faster processing.")
print("  2. Reduce 'Color Morph Kernel' and 'Edge Morph Kernel' sizes.")
print("  3. Consider setting 'Use Bilateral Filter' to 0 (off).")
print("  4. Reduce 'Display Height' in the code (around line ~350) for smaller preview windows.")
print("  5. Temporarily comment out some intermediate mask displays in `np.hstack` if needed.")
print("-------------------------------------")
print("Press 'd' or Right Arrow to go to the next image.")
print("Press 'a' or Left Arrow to go to the previous image.")
print("Press 's' to print current parameter values to the console.")
print("Press 'q' to quit.")


# --- HSV Color Space Sliders (for the target line detection AFTER Normalization) ---
cv2.createTrackbar("H_Lower", "Tuning", 5, 179, lambda x: None)
cv2.createTrackbar("H_Upper", "Tuning", 22, 179, lambda x: None)
cv2.createTrackbar("S_Lower", "Tuning", 100, 255, lambda x: None)
cv2.createTrackbar("S_Upper", "Tuning", 255, 255, lambda x: None)
cv2.createTrackbar("V_Lower", "Tuning", 100, 255, lambda x: None)
cv2.createTrackbar("V_Upper", "Tuning", 255, 255, lambda x: None)

# --- CLAHE (Contrast Limited Adaptive Histogram Equalization) Parameters ---
cv2.createTrackbar("CLAHE Clip Limit", "Tuning", 20, 100, lambda x: None) # Default 2.0 (scaled by 10)
cv2.createTrackbar("CLAHE Tile Grid Size", "Tuning", 8, 20, lambda x: None) # Default 8x8 (max 20x20)

# Processing Scale Trackbar
cv2.createTrackbar("Processing Scale (%)", "Tuning", 100, 100, lambda x: None) # 100% means original size, 50% means half size

# Morphological Kernel for Color Mask
cv2.createTrackbar("Color Morph Kernel", "Tuning", 5, 50, lambda x: None)

# Edge Pre-processing Filter
cv2.createTrackbar("Use Bilateral Filter", "Tuning", 1, 1, lambda x: None)
cv2.createTrackbar("Bilateral D", "Tuning", 9, 20, lambda x: None)
cv2.createTrackbar("Bilateral SigmaColor", "Tuning", 75, 200, lambda x: None)
cv2.createTrackbar("Bilateral SigmaSpace", "Tuning", 75, 200, lambda x: None)

# Canny Edge Detector Thresholds
cv2.createTrackbar("Canny Thresh1", "Tuning", 50, 255, lambda x: None)
cv2.createTrackbar("Canny Thresh2", "Tuning", 150, 255, lambda x: None)

# Morphological Kernel for Edge Mask
cv2.createTrackbar("Edge Morph Kernel", "Tuning", 7, 50, lambda x: None)

# Hough Line Transform Parameters
cv2.createTrackbar("Hough Threshold", "Tuning", 50, 200, lambda x: None)
cv2.createTrackbar("Hough Min Length", "Tuning", 30, 500, lambda x: None)
cv2.createTrackbar("Hough Max Gap", "Tuning", 50, 200, lambda x: None)

# Line Filtering Parameters
cv2.createTrackbar("Max Line Angle (deg)", "Tuning", 20, 90, lambda x: None)

# Image Cropping Parameters
cv2.createTrackbar("Crop % from Top", "Tuning", 75, 100, lambda x: None)
cv2.createTrackbar("Crop % from Left", "Tuning", 0, 49, lambda x: None)
cv2.createTrackbar("Crop % from Right", "Tuning", 0, 49, lambda x: None)


# --- Main Loop ---
while True:
    frame_start_time = time.time()
    filename = image_files[current_index]
    print(f"Processing: {filename} (Index: {current_index})")

    filepath = os.path.join(image_folder, filename)
    image = cv2.imread(filepath)
    if image is None:
        print(f"❌ ERROR: Cannot read {filename}. Skipping to next image.")
        current_index = (current_index + 1) % len(image_files)
        continue

    # --- Get current trackbar values ---
    # HSV
    lh = cv2.getTrackbarPos("H_Lower", "Tuning")
    uh = cv2.getTrackbarPos("H_Upper", "Tuning")
    ls = cv2.getTrackbarPos("S_Lower", "Tuning")
    us = cv2.getTrackbarPos("S_Upper", "Tuning")
    lv = cv2.getTrackbarPos("V_Lower", "Tuning")
    uv = cv2.getTrackbarPos("V_Upper", "Tuning")

    # CLAHE
    clahe_clip_limit = cv2.getTrackbarPos("CLAHE Clip Limit", "Tuning") / 10.0 # Scale from 1-100 to 0.1-10.0
    clahe_tile_grid_size = max(1, cv2.getTrackbarPos("CLAHE Tile Grid Size", "Tuning")) # Ensure at least 1x1

    processing_scale_percent = cv2.getTrackbarPos("Processing Scale (%)", "Tuning") / 100.0
    if processing_scale_percent <= 0: processing_scale_percent = 0.01 # Avoid division by zero/too small

    color_morph_kernel_size = max(1, cv2.getTrackbarPos("Color Morph Kernel", "Tuning"))
    
    use_bilateral = cv2.getTrackbarPos("Use Bilateral Filter", "Tuning")
    bilateral_d = max(1, cv2.getTrackbarPos("Bilateral D", "Tuning"))
    bilateral_sigma_color = max(1, cv2.getTrackbarPos("Bilateral SigmaColor", "Tuning"))
    bilateral_sigma_space = max(1, cv2.getTrackbarPos("Bilateral SigmaSpace", "Tuning"))

    canny_thresh1 = cv2.getTrackbarPos("Canny Thresh1", "Tuning")
    canny_thresh2 = cv2.getTrackbarPos("Canny Thresh2", "Tuning")
    edge_morph_kernel_size = max(1, cv2.getTrackbarPos("Edge Morph Kernel", "Tuning"))
    
    hough_threshold = cv2.getTrackbarPos("Hough Threshold", "Tuning")
    hough_min_length = cv2.getTrackbarPos("Hough Min Length", "Tuning")
    hough_max_gap = cv2.getTrackbarPos("Hough Max Gap", "Tuning")

    max_line_angle_deg = cv2.getTrackbarPos("Max Line Angle (deg)", "Tuning")
    
    crop_percent_top = cv2.getTrackbarPos("Crop % from Top", "Tuning")
    crop_percent_left = cv2.getTrackbarPos("Crop % from Left", "Tuning")
    crop_percent_right = cv2.getTrackbarPos("Crop % from Right", "Tuning")

    # --- 1. Apply Cropping ---
    crop_start_time = time.time()
    original_h, original_w, _ = image.shape

    crop_y_start = int(original_h * crop_percent_top / 100)
    if crop_y_start >= original_h:
        crop_y_start = original_h - 1
    
    crop_x_start = int(original_w * crop_percent_left / 100)
    crop_x_end = original_w - int(original_w * crop_percent_right / 100)

    if crop_x_start >= crop_x_end:
        crop_x_start = 0
        crop_x_end = original_w

    cropped_image = image[crop_y_start:original_h, crop_x_start:crop_x_end].copy()
    cropped_h, cropped_w, _ = cropped_image.shape
    print(f"  Cropping: {(time.time() - crop_start_time):.4f}s")

    # --- 2. Resize for Processing Performance ---
    processing_width = int(cropped_w * processing_scale_percent)
    processing_height = int(cropped_h * processing_scale_percent)
    
    # Ensure minimum size to avoid errors
    if processing_width < 1: processing_width = 1
    if processing_height < 1: processing_height = 1

    preprocess_resize_start_time = time.time()
    cropped_image_for_processing = cv2.resize(cropped_image, (processing_width, processing_height), interpolation=cv2.INTER_LINEAR)
    print(f"  Pre-processing Resize: {(time.time() - preprocess_resize_start_time):.4f}s")


    # --- 3. Illumination Normalization (CLAHE) ---
    clahe_start_time = time.time()
    
    # Convert to HSV color space
    hsv_image = cv2.cvtColor(cropped_image_for_processing, cv2.COLOR_BGR2HSV)
    
    # Split the HSV image into H, S, and V channels
    h, s, v = cv2.split(hsv_image)
    
    # Create CLAHE object
    clahe = cv2.createCLAHE(clipLimit=clahe_clip_limit, tileGridSize=(clahe_tile_grid_size, clahe_tile_grid_size))
    
    # Apply CLAHE to the V-channel
    v_clahe = clahe.apply(v)
    
    # Merge the enhanced V-channel back with H and S channels
    normalized_hsv = cv2.merge([h, s, v_clahe])
    
    # Convert back to BGR
    normalized_image = cv2.cvtColor(normalized_hsv, cv2.COLOR_HSV2BGR)
    print(f"  CLAHE Processing: {(time.time() - clahe_start_time):.4f}s")

    # --- 4. Color Masking (HSV on CLAHE-processed image) ---
    color_mask_start_time = time.time()
    hsv_normalized = cv2.cvtColor(normalized_image, cv2.COLOR_BGR2HSV)
    
    lower_hsv = np.array([lh, ls, lv])
    upper_hsv = np.array([uh, us, uv])
    color_mask = cv2.inRange(hsv_normalized, lower_hsv, upper_hsv)
    print(f"  Color Masking: {(time.time() - color_mask_start_time):.4f}s")

    # --- 5. Morphological Operations on the Color Mask ---
    morph_color_start_time = time.time()
    color_morph_kernel = np.ones((color_morph_kernel_size, color_morph_kernel_size), np.uint8)
    # Use MORPH_OPEN to remove small objects/noise
    color_mask_morphed = cv2.morphologyEx(color_mask, cv2.MORPH_OPEN, color_morph_kernel, iterations=1)
    # Dilate to connect broken parts
    color_mask_morphed = cv2.dilate(color_mask_morphed, color_morph_kernel, iterations=1)
    # Use MORPH_CLOSE to close small holes and connect nearby components
    color_mask_morphed = cv2.morphologyEx(color_mask_morphed, cv2.MORPH_CLOSE, color_morph_kernel, iterations=1)
    print(f"  Color Morph: {(time.time() - morph_color_start_time):.4f}s")
    
    # --- 6. Edge Detection (Canny) ---
    edge_detect_start_time = time.time()
    gray_normalized = cv2.cvtColor(normalized_image, cv2.COLOR_BGR2GRAY)
    
    if use_bilateral:
        filtered_gray = cv2.bilateralFilter(gray_normalized, bilateral_d, bilateral_sigma_color, bilateral_sigma_space)
    else:
        # Using a small default Gaussian blur if bilateral is off
        filtered_gray = cv2.GaussianBlur(gray_normalized, (5, 5), 0) 

    edge_mask = cv2.Canny(filtered_gray, canny_thresh1, canny_thresh2)

    edge_morph_kernel = np.ones((edge_morph_kernel_size, edge_morph_kernel_size), np.uint8)
    edge_mask_morphed = cv2.morphologyEx(edge_mask, cv2.MORPH_CLOSE, edge_morph_kernel, iterations=1)
    print(f"  Edge Detect & Morph: {(time.time() - edge_detect_start_time):.4f}s")

    # --- 7. Combine Masks and Line Detection ---
    line_detection_start_time = time.time()
    final_mask = cv2.bitwise_and(color_mask_morphed, edge_mask_morphed)

    lines = cv2.HoughLinesP(final_mask, 1, np.pi / 180,
                            hough_threshold,
                            minLineLength=hough_min_length,
                            maxLineGap=hough_max_gap)

    # --- 8. Prepare Preview and Calculate Deviation Score ---
    preview = image.copy()
    # Draw ROI rectangle on original image
    cv2.rectangle(preview, (crop_x_start, crop_y_start), (crop_x_end, original_h), (255, 0, 255), 2)
    # Draw center line on original image
    center_x_full_img = original_w // 2
    cv2.line(preview, (center_x_full_img, crop_y_start), (center_x_full_img, original_h), (0, 255, 255), 2)

    deviation_score = float('nan')
    display_text = "NO LINE"
    cx_full_img = -1 

    filtered_lines = []
    if lines is not None:
        # Scale lines back to original cropped_image dimensions for drawing
        # (This is important because `final_mask` was created from `cropped_image_for_processing`)
        scale_x = cropped_w / processing_width
        scale_y = cropped_h / processing_height
        
        for line in lines:
            x1, y1, x2, y2 = line[0]
            
            # Scale coordinates back to original cropped image size
            x1_orig = int(x1 * scale_x)
            y1_orig = int(y1 * scale_y)
            x2_orig = int(x2 * scale_x)
            y2_orig = int(y2 * scale_y)

            # Calculate angle of the line
            angle_rad = math.atan2(y2_orig - y1_orig, x2_orig - x1_orig)
            angle_deg = math.degrees(angle_rad)

            # Filter lines by angle (e.g., to keep mostly horizontal or near-horizontal lines)
            if abs(angle_deg) < max_line_angle_deg or abs(angle_deg - 180) < max_line_angle_deg:
                filtered_lines.append((x1_orig, y1_orig, x2_orig, y2_orig)) # Store original-scaled coords

    if filtered_lines:
        all_line_midpoints_x = []
        for x1, y1, x2, y2 in filtered_lines:
            cv2.line(preview,
                     (x1 + crop_x_start, y1 + crop_y_start), # Add crop_x_start to shift to full image coords
                     (x2 + crop_x_start, y2 + crop_y_start), # Add crop_x_start to shift to full image coords
                     (0, 255, 0), 2) # Green color for detected lines
            all_line_midpoints_x.append((x1 + x2) // 2)
        
        # Calculate the average X-coordinate of all filtered line midpoints within the cropped area
        cx_cropped_scaled = int(np.mean(all_line_midpoints_x))
        # Convert this X-coordinate back to the full original image's coordinate system
        cx_full_img = cx_cropped_scaled + crop_x_start
        # Y-coordinate for the centroid visualization (arbitrary, usually center of ROI)
        cy_full_img = crop_y_start + (original_h - crop_y_start) // 2 

        # Draw centroid and its coordinate on the preview image
        cv2.circle(preview, (cx_full_img, cy_full_img), 6, (0, 0, 255), -1) # Red circle
        cv2.putText(preview, f"cx: {cx_full_img}", (cx_full_img + 10, cy_full_img), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

        # Calculate deviation score
        if center_x_full_img != 0:
            deviation_score = (cx_full_img - center_x_full_img) / center_x_full_img
        else:
            deviation_score = 0.0 # Handle case where center_x_full_img is 0 (shouldn't happen for typical images)

        display_text = f"Deviation: {deviation_score:.2f}"
    
    cv2.putText(preview, display_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2) # Yellow text
    print(f"  Line Detection & Draw: {(time.time() - line_detection_start_time):.4f}s")

    # --- 9. Display images with consistent, larger size ---
    display_start_time = time.time()
    # You can reduce this further for more speed. Try 200 or 150 if still too slow.
    display_height = 300 
    
    # Calculate display width based on original image's aspect ratio
    aspect_ratio_orig = original_w / original_h
    display_width = int(display_height * aspect_ratio_orig)

    preview_resized = cv2.resize(preview, (display_width, display_height))
    cropped_image_resized = cv2.resize(cropped_image, (display_width, display_height))
    
    # Normalized image was processed at 'processing_width' x 'processing_height', resize to display size
    normalized_display_resized = cv2.resize(normalized_image, (display_width, display_height))

    # Convert masks to BGR for display purposes (so they show up as grayscale images)
    color_mask_resized = cv2.resize(cv2.cvtColor(color_mask, cv2.COLOR_GRAY2BGR), (display_width, display_height))
    morphed_mask_resized = cv2.resize(cv2.cvtColor(color_mask_morphed, cv2.COLOR_GRAY2BGR), (display_width, display_height))
    edge_mask_morphed_resized = cv2.resize(cv2.cvtColor(edge_mask_morphed, cv2.COLOR_GRAY2BGR), (display_width, display_height))
    final_mask_resized = cv2.resize(cv2.cvtColor(final_mask, cv2.COLOR_GRAY2BGR), (display_width, display_height))

    # Stack all images horizontally for display
    combined_display = np.hstack((
        preview_resized,
        cropped_image_resized,
        normalized_display_resized, # Now displays CLAHE processed image
        color_mask_resized,
        morphed_mask_resized,
        edge_mask_morphed_resized,
        final_mask_resized
    ))

    cv2.imshow("Tuning", combined_display)
    print(f"  Display Update: {(time.time() - display_start_time):.4f}s")
    print(f"Total frame time: {(time.time() - frame_start_time):.4f}s\n")

    # --- Keyboard Controls ---
    key = cv2.waitKey(30) & 0xFF # Wait 30ms for a key press
    if key == ord("q"): # Press 'q' to quit
        break
    elif key in [ord("d"), 83]: # Press 'd' or Right Arrow to go to the next image (ASCII for Right Arrow)
        current_index = (current_index + 1) % len(image_files)
    elif key in [ord("a"), 81]: # Press 'a' or Left Arrow to go to the previous image (ASCII for Left Arrow)
        current_index = (current_index - 1 + len(image_files)) % len(image_files)
    elif key == ord("s"): # Press 's' to print current parameters to console
        print(f"\n--- Saved Parameters for {filename} ---")
        print(f"hsv_lower = np.array([{lh}, {ls}, {lv}])")
        print(f"hsv_upper = np.array([{uh}, {us}, {uv}])")
        print(f"clahe_clip_limit = {clahe_clip_limit}")
        print(f"clahe_tile_grid_size = {clahe_tile_grid_size}")
        print(f"processing_scale_percent = {processing_scale_percent}")
        print(f"color_morph_kernel_size = {color_morph_kernel_size}")
        print(f"use_bilateral_filter = {use_bilateral}")
        print(f"bilateral_d = {bilateral_d}")
        print(f"bilateral_sigma_color = {bilateral_sigma_color}")
        print(f"bilateral_sigma_space = {bilateral_sigma_space}")
        print(f"canny_thresh1 = {canny_thresh1}")
        print(f"canny_thresh2 = {canny_thresh2}")
        print(f"edge_morph_kernel_size = {edge_morph_kernel_size}")
        print(f"hough_threshold = {hough_threshold}")
        print(f"hough_min_length = {hough_min_length}")
        print(f"hough_max_gap = {hough_max_gap}")
        print(f"max_line_angle_deg = {max_line_angle_deg}")
        print(f"crop_percent_top = {crop_percent_top}")
        print(f"crop_percent_left = {crop_percent_left}")
        print(f"crop_percent_right = {crop_percent_right}")
        
        if math.isnan(deviation_score):
            print(f"Calculated Deviation: NO LINE (cx={cx_full_img})\n")
        else:
            print(f"Calculated Deviation: {deviation_score:.2f} (cx={cx_full_img})\n")

cv2.destroyAllWindows()
# Out:
# Loaded 1291 images.
#
# --- Tuning Guide ---
# This version uses CLAHE (Contrast Limited Adaptive Histogram Equalization) for illumination normalization.
# The image is scaled down for processing to improve performance.
# First, focus on 'CLAHE Clip Limit' and 'CLAHE Tile Grid Size' to normalize image brightness.
# Then, adjust 'H_Lower', 'H_Upper', 'S_Lower', 'S_Upper', 'V_Lower', 'V_Upper' on the *CLAHE-processed* image.
# Observe 'CLAHE Processed Image', 'Color Mask (CLAHE+HSV)', and 'Final Mask' carefully.
#
# --- Performance Tips (if still laggy): ---
#   1. **Crucial:** Adjust 'Processing Scale (%)'. Smaller values mean faster processing.
#   2. Reduce 'Color Morph Kernel' and 'Edge Morph Kernel' sizes.
#   3. Consider setting 'Use Bilateral Filter' to 0 (off).
#   4. Reduce 'Display Height' in the code (around line ~350) for smaller preview windows.
#   5. Temporarily comment out some intermediate mask displays in `np.hstack` if needed.
# -------------------------------------
# Press 'd' or Right Arrow to go to the next image.
# Press 'a' or Left Arrow to go to the previous image.
# Press 's' to print current parameter values to the console.
# Press 'q' to quit.
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0073s
#   Color Masking: 0.0019s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0153s
#   Line Detection & Draw: 0.0047s
#   Display Update: 0.0082s
# Total frame time: 0.1324s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0058s
#   Color Masking: 0.0010s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0135s
#   Line Detection & Draw: 0.0052s
#   Display Update: 0.0093s
# Total frame time: 0.1307s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0059s
#   Color Masking: 0.0012s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0126s
#   Line Detection & Draw: 0.0046s
#   Display Update: 0.0079s
# Total frame time: 0.1267s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0013s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0131s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0073s
# Total frame time: 0.1249s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0061s
#   Color Masking: 0.0010s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0130s
#   Line Detection & Draw: 0.0048s
#   Display Update: 0.0078s
# Total frame time: 0.1253s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0044s
#   Color Masking: 0.0028s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0132s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0070s
# Total frame time: 0.1242s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0014s
#   Color Morph: 0.0015s
#   Edge Detect & Morph: 0.0135s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0074s
# Total frame time: 0.1258s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0013s
#   Color Morph: 0.0015s
#   Edge Detect & Morph: 0.0148s
#   Line Detection & Draw: 0.0048s
#   Display Update: 0.0090s
# Total frame time: 0.1340s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0053s
#   Color Masking: 0.0010s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0143s
#   Line Detection & Draw: 0.0046s
#   Display Update: 0.0086s
# Total frame time: 0.1271s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0022s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0141s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0067s
# Total frame time: 0.1387s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0025s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0138s
#   Line Detection & Draw: 0.0050s
#   Display Update: 0.0085s
# Total frame time: 0.1404s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0057s
#   Color Masking: 0.0011s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0134s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0102s
# Total frame time: 0.1391s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0129s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0113s
# Total frame time: 0.1404s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0052s
#   Color Masking: 0.0028s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0129s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0117s
# Total frame time: 0.1351s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0060s
#   Color Masking: 0.0012s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0150s
#   Line Detection & Draw: 0.0046s
#   Display Update: 0.0091s
# Total frame time: 0.1328s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0059s
#   Color Masking: 0.0013s
#   Color Morph: 0.0014s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0093s
# Total frame time: 0.1277s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0055s
#   Color Masking: 0.0010s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0140s
#   Line Detection & Draw: 0.0043s
#   Display Update: 0.0083s
# Total frame time: 0.1352s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0046s
#   Color Masking: 0.0014s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0128s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0096s
# Total frame time: 0.1352s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0054s
#   Color Masking: 0.0015s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0053s
#   Display Update: 0.0101s
# Total frame time: 0.1348s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0020s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0135s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0104s
# Total frame time: 0.1356s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0053s
#   Color Masking: 0.0021s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0141s
#   Line Detection & Draw: 0.0045s
#   Display Update: 0.0083s
# Total frame time: 0.1266s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0044s
#   Color Masking: 0.0023s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0145s
#   Line Detection & Draw: 0.0042s
#   Display Update: 0.0114s
# Total frame time: 0.1385s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0043s
#   Color Masking: 0.0012s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0091s
# Total frame time: 0.1443s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0024s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0087s
# Total frame time: 0.1314s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0065s
#   Color Masking: 0.0010s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0141s
#   Line Detection & Draw: 0.0043s
#   Display Update: 0.0110s
# Total frame time: 0.1352s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0023s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0126s
#   Line Detection & Draw: 0.0042s
#   Display Update: 0.0091s
# Total frame time: 0.1326s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0012s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0142s
#   Line Detection & Draw: 0.0043s
#   Display Update: 0.0080s
# Total frame time: 0.1318s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0053s
#   Color Masking: 0.0013s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0137s
#   Line Detection & Draw: 0.0043s
#   Display Update: 0.0104s
# Total frame time: 0.1296s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0131s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0085s
# Total frame time: 0.1279s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0057s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0136s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0091s
# Total frame time: 0.1286s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0059s
#   Color Masking: 0.0023s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0148s
#   Line Detection & Draw: 0.0048s
#   Display Update: 0.0103s
# Total frame time: 0.1372s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0051s
#   Color Masking: 0.0020s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0139s
#   Line Detection & Draw: 0.0046s
#   Display Update: 0.0086s
# Total frame time: 0.1279s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0022s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0130s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0110s
# Total frame time: 0.1395s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0057s
#   Color Masking: 0.0014s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0164s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0115s
# Total frame time: 0.1328s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0013s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0062s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0155s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0101s
# Total frame time: 0.1408s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0050s
#   Color Masking: 0.0020s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0139s
#   Line Detection & Draw: 0.0040s
#   Display Update: 0.0083s
# Total frame time: 0.1313s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0057s
#   Color Masking: 0.0014s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0097s
# Total frame time: 0.1358s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0012s
#   Color Morph: 0.0014s
#   Edge Detect & Morph: 0.0137s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0112s
# Total frame time: 0.1375s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0055s
#   Color Masking: 0.0015s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0124s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0104s
# Total frame time: 0.1393s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0134s
#   Line Detection & Draw: 0.0042s
#   Display Update: 0.0092s
# Total frame time: 0.1354s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0060s
#   Color Masking: 0.0010s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0129s
#   Line Detection & Draw: 0.0047s
#   Display Update: 0.0115s
# Total frame time: 0.1314s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0049s
#   Color Masking: 0.0025s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0135s
#   Line Detection & Draw: 0.0046s
#   Display Update: 0.0092s
# Total frame time: 0.1418s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0013s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0134s
#   Line Detection & Draw: 0.0050s
#   Display Update: 0.0086s
# Total frame time: 0.1321s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0014s
#   CLAHE Processing: 0.0057s
#   Color Masking: 0.0010s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0137s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0079s
# Total frame time: 0.1256s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0044s
#   Color Masking: 0.0010s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0168s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0079s
# Total frame time: 0.1379s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0011s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0046s
#   Display Update: 0.0036s
# Total frame time: 0.1143s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0025s
#   Display Update: 0.0043s
# Total frame time: 0.0992s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0034s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0033s
#   Display Update: 0.0032s
# Total frame time: 0.0995s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0013s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0023s
#   Display Update: 0.0042s
# Total frame time: 0.1012s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0024s
#   Display Update: 0.0043s
# Total frame time: 0.1058s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0034s
#   Display Update: 0.0033s
# Total frame time: 0.1046s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0013s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0031s
#   Display Update: 0.0041s
# Total frame time: 0.1008s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0014s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0035s
#   Display Update: 0.0043s
# Total frame time: 0.1023s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0010s
#   Line Detection & Draw: 0.0021s
#   Display Update: 0.0036s
# Total frame time: 0.1088s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0010s
#   Line Detection & Draw: 0.0032s
#   Display Update: 0.0041s
# Total frame time: 0.1041s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0012s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0013s
#   Line Detection & Draw: 0.0024s
#   Display Update: 0.0044s
# Total frame time: 0.1074s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0010s
#   Line Detection & Draw: 0.0032s
#   Display Update: 0.0043s
# Total frame time: 0.1057s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0010s
#   Line Detection & Draw: 0.0031s
#   Display Update: 0.0044s
# Total frame time: 0.1060s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0024s
#   Line Detection & Draw: 0.0023s
#   Display Update: 0.0045s
# Total frame time: 0.1106s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0011s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0013s
#   Line Detection & Draw: 0.0033s
#   Display Update: 0.0041s
# Total frame time: 0.1071s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0010s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0020s
#   Line Detection & Draw: 0.0030s
#   Display Update: 0.0041s
# Total frame time: 0.1028s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0022s
#   Line Detection & Draw: 0.0033s
#   Display Update: 0.0035s
# Total frame time: 0.1093s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0014s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0011s
#   Line Detection & Draw: 0.0039s
#   Display Update: 0.0037s
# Total frame time: 0.1092s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0010s
#   Line Detection & Draw: 0.0030s
#   Display Update: 0.0040s
# Total frame time: 0.1051s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0012s
#   Line Detection & Draw: 0.0030s
#   Display Update: 0.0041s
# Total frame time: 0.1010s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0010s
#   Line Detection & Draw: 0.0030s
#   Display Update: 0.0043s
# Total frame time: 0.1005s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0011s
#   Line Detection & Draw: 0.0033s
#   Display Update: 0.0034s
# Total frame time: 0.1061s
#
# Processing: 00420478.png (Index: 0)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0011s
#   Line Detection & Draw: 0.0022s
#   Display Update: 0.0043s
# Total frame time: 0.1100s
#
# Processing: 00420523.png (Index: 1)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0010s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0034s
#   Display Update: 0.0033s
# Total frame time: 0.0978s
#
# Processing: 00420523.png (Index: 1)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0011s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0011s
#   Line Detection & Draw: 0.0025s
#   Display Update: 0.0038s
# Total frame time: 0.1079s
#
# Processing: 00420564.png (Index: 2)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0011s
#   Line Detection & Draw: 0.0025s
#   Display Update: 0.0043s
# Total frame time: 0.1007s
#
# Processing: 00420604.png (Index: 3)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0010s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0033s
#   Display Update: 0.0041s
# Total frame time: 0.1097s
#
# Processing: 00420604.png (Index: 3)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0000s
#   Line Detection & Draw: 0.0033s
#   Display Update: 0.0038s
# Total frame time: 0.1173s
#
# Processing: 00420644.png (Index: 4)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0010s
#   Line Detection & Draw: 0.0030s
#   Display Update: 0.0046s
# Total frame time: 0.1113s
#
# Processing: 00420684.png (Index: 5)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0000s
#   Color Masking: 0.0010s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0011s
#   Line Detection & Draw: 0.0035s
#   Display Update: 0.0041s
# Total frame time: 0.1147s
#
# Processing: 00420725.png (Index: 6)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0012s
#   Line Detection & Draw: 0.0034s
#   Display Update: 0.0044s
# Total frame time: 0.1058s
#
# Processing: 00420765.png (Index: 7)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0011s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0027s
#   Line Detection & Draw: 0.0035s
#   Display Update: 0.0050s
# Total frame time: 0.1108s
#
# Processing: 00420803.png (Index: 8)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0000s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0035s
#   Line Detection & Draw: 0.0045s
#   Display Update: 0.0044s
# Total frame time: 0.1079s
#
# Processing: 00420841.png (Index: 9)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0000s
#   CLAHE Processing: 0.0010s
#   Color Masking: 0.0010s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0043s
#   Line Detection & Draw: 0.0032s
#   Display Update: 0.0047s
# Total frame time: 0.1072s
#
# Processing: 00420841.png (Index: 9)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0036s
#   Color Masking: 0.0011s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0066s
#   Line Detection & Draw: 0.0043s
#   Display Update: 0.0060s
# Total frame time: 0.1293s
#
# Processing: 00420878.png (Index: 10)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0014s
#   Color Masking: 0.0014s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0062s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0056s
# Total frame time: 0.1160s
#
# Processing: 00420915.png (Index: 11)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0038s
#   Color Masking: 0.0013s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0105s
#   Line Detection & Draw: 0.0048s
#   Display Update: 0.0087s
# Total frame time: 0.1272s
#
# Processing: 00420952.png (Index: 12)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0022s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0141s
#   Line Detection & Draw: 0.0077s
#   Display Update: 0.0077s
# Total frame time: 0.1421s
#
# Processing: 00420989.png (Index: 13)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0012s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0139s
#   Line Detection & Draw: 0.0042s
#   Display Update: 0.0070s
# Total frame time: 0.1302s
#
# Processing: 00421026.png (Index: 14)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0023s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0144s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0082s
# Total frame time: 0.1325s
#
# Processing: 00421026.png (Index: 14)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0044s
#   Color Masking: 0.0013s
#   Color Morph: 0.0015s
#   Edge Detect & Morph: 0.0138s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0081s
# Total frame time: 0.1410s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0054s
#   Color Masking: 0.0013s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0120s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0084s
# Total frame time: 0.1286s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0023s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0124s
#   Line Detection & Draw: 0.0060s
#   Display Update: 0.0089s
# Total frame time: 0.1370s
#
# Processing: 00421100.png (Index: 16)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0050s
#   Color Masking: 0.0022s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0136s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0081s
# Total frame time: 0.1265s
#
# Processing: 00421100.png (Index: 16)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0049s
#   Color Masking: 0.0010s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0080s
# Total frame time: 0.1374s
#
# Processing: 00421100.png (Index: 16)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0010s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0110s
# Total frame time: 0.1323s
#
# Processing: 00421100.png (Index: 16)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0054s
#   Color Masking: 0.0014s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0121s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0085s
# Total frame time: 0.1369s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0043s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0139s
#   Line Detection & Draw: 0.0058s
#   Display Update: 0.0067s
# Total frame time: 0.1285s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0011s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0118s
#   Line Detection & Draw: 0.0060s
#   Display Update: 0.0066s
# Total frame time: 0.1254s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0050s
#   Color Masking: 0.0015s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0128s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0110s
# Total frame time: 0.1311s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0055s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0145s
#   Line Detection & Draw: 0.0050s
#   Display Update: 0.0121s
# Total frame time: 0.1387s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0013s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0051s
#   Color Masking: 0.0013s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0119s
#   Line Detection & Draw: 0.0053s
#   Display Update: 0.0100s
# Total frame time: 0.1322s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0155s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0111s
# Total frame time: 0.1360s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0042s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0140s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0115s
# Total frame time: 0.1460s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0021s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0125s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0129s
# Total frame time: 0.1360s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0015s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0138s
#   Line Detection & Draw: 0.0060s
#   Display Update: 0.0106s
# Total frame time: 0.1409s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0058s
#   Color Masking: 0.0011s
#   Color Morph: 0.0015s
#   Edge Detect & Morph: 0.0125s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0120s
# Total frame time: 0.1370s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0036s
#   Color Masking: 0.0021s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0135s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0074s
# Total frame time: 0.1357s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0054s
#   Color Masking: 0.0022s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0132s
#   Line Detection & Draw: 0.0060s
#   Display Update: 0.0108s
# Total frame time: 0.1334s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0010s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0152s
#   Line Detection & Draw: 0.0053s
#   Display Update: 0.0100s
# Total frame time: 0.1373s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0015s
#   CLAHE Processing: 0.0046s
#   Color Masking: 0.0015s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0128s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0067s
# Total frame time: 0.1265s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0014s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0132s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0064s
# Total frame time: 0.1339s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0022s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0122s
#   Line Detection & Draw: 0.0066s
#   Display Update: 0.0078s
# Total frame time: 0.1286s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0013s
#   Color Morph: 0.0015s
#   Edge Detect & Morph: 0.0134s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0080s
# Total frame time: 0.1318s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0027s
#   CLAHE Processing: 0.0043s
#   Color Masking: 0.0021s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0128s
#   Line Detection & Draw: 0.0053s
#   Display Update: 0.0071s
# Total frame time: 0.1275s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0058s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0126s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0076s
# Total frame time: 0.1314s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0046s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0139s
#   Line Detection & Draw: 0.0066s
#   Display Update: 0.0123s
# Total frame time: 0.1357s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0048s
#   Color Masking: 0.0025s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0138s
#   Line Detection & Draw: 0.0062s
#   Display Update: 0.0078s
# Total frame time: 0.1317s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0049s
#   Color Masking: 0.0012s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0143s
#   Line Detection & Draw: 0.0067s
#   Display Update: 0.0117s
# Total frame time: 0.1417s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0052s
#   Color Masking: 0.0022s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0146s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0130s
# Total frame time: 0.1793s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0022s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0130s
#   Line Detection & Draw: 0.0066s
#   Display Update: 0.0090s
# Total frame time: 0.1372s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0050s
#   Color Masking: 0.0010s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0143s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0117s
# Total frame time: 0.1481s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0053s
#   Color Masking: 0.0013s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0138s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0106s
# Total frame time: 0.1407s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0014s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0137s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0120s
# Total frame time: 0.1372s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0014s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0145s
#   Line Detection & Draw: 0.0053s
#   Display Update: 0.0091s
# Total frame time: 0.1435s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0041s
#   Color Masking: 0.0014s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0137s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0133s
# Total frame time: 0.1424s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0054s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0134s
#   Line Detection & Draw: 0.0048s
#   Display Update: 0.0112s
# Total frame time: 0.1314s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0040s
#   Color Masking: 0.0014s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0122s
#   Line Detection & Draw: 0.0061s
#   Display Update: 0.0124s
# Total frame time: 0.1343s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0047s
#   Color Masking: 0.0027s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0138s
#   Line Detection & Draw: 0.0061s
#   Display Update: 0.0081s
# Total frame time: 0.1440s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0013s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0116s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0091s
# Total frame time: 0.1324s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0043s
#   Color Masking: 0.0010s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0124s
#   Line Detection & Draw: 0.0057s
#   Display Update: 0.0105s
# Total frame time: 0.1331s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0053s
#   Color Masking: 0.0011s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0045s
#   Display Update: 0.0101s
# Total frame time: 0.1309s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0035s
#   Color Masking: 0.0011s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0136s
#   Line Detection & Draw: 0.0061s
#   Display Update: 0.0101s
# Total frame time: 0.1376s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0010s
#   Color Morph: 0.0014s
#   Edge Detect & Morph: 0.0120s
#   Line Detection & Draw: 0.0060s
#   Display Update: 0.0134s
# Total frame time: 0.1349s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0044s
#   Color Masking: 0.0010s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0150s
#   Line Detection & Draw: 0.0052s
#   Display Update: 0.0111s
# Total frame time: 0.1333s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0045s
#   Color Masking: 0.0010s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0125s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0085s
# Total frame time: 0.1281s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0036s
#   Color Masking: 0.0021s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0138s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0112s
# Total frame time: 0.1387s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0043s
#   Color Masking: 0.0013s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0143s
#   Line Detection & Draw: 0.0070s
#   Display Update: 0.0081s
# Total frame time: 0.1362s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0038s
#   Color Masking: 0.0024s
#   Color Morph: 0.0000s
#   Edge Detect & Morph: 0.0148s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0069s
# Total frame time: 0.1288s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0046s
#   Color Masking: 0.0024s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0114s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0092s
# Total frame time: 0.1328s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0042s
#   Color Masking: 0.0012s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0136s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0100s
# Total frame time: 0.1376s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0010s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0131s
#   Line Detection & Draw: 0.0057s
#   Display Update: 0.0105s
# Total frame time: 0.1444s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0043s
#   Color Masking: 0.0014s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0128s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0118s
# Total frame time: 0.1332s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0054s
#   Color Masking: 0.0010s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0134s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0097s
# Total frame time: 0.1364s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0040s
#   CLAHE Processing: 0.0140s
#   Color Masking: 0.0044s
#   Color Morph: 0.0035s
#   Edge Detect & Morph: 0.0245s
#   Line Detection & Draw: 0.0115s
#   Display Update: 0.0101s
# Total frame time: 0.1657s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0020s
#   Pre-processing Resize: 0.0040s
#   CLAHE Processing: 0.0143s
#   Color Masking: 0.0045s
#   Color Morph: 0.0030s
#   Edge Detect & Morph: 0.0218s
#   Line Detection & Draw: 0.0115s
#   Display Update: 0.0097s
# Total frame time: 0.1634s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0033s
#   CLAHE Processing: 0.0129s
#   Color Masking: 0.0048s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.0213s
#   Line Detection & Draw: 0.0116s
#   Display Update: 0.0131s
# Total frame time: 0.1671s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0021s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0110s
#   Color Masking: 0.0050s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0151s
#   Line Detection & Draw: 0.0078s
#   Display Update: 0.0108s
# Total frame time: 0.1545s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0022s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0110s
#   Color Masking: 0.0036s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0156s
#   Line Detection & Draw: 0.0077s
#   Display Update: 0.0103s
# Total frame time: 0.1579s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0022s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0108s
#   Color Masking: 0.0033s
#   Color Morph: 0.0035s
#   Edge Detect & Morph: 0.0152s
#   Line Detection & Draw: 0.0079s
#   Display Update: 0.0097s
# Total frame time: 0.1595s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0025s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0090s
#   Color Masking: 0.0037s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0131s
#   Line Detection & Draw: 0.0076s
#   Display Update: 0.0109s
# Total frame time: 0.1470s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0092s
#   Color Masking: 0.0031s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.0121s
#   Line Detection & Draw: 0.0071s
#   Display Update: 0.0103s
# Total frame time: 0.1497s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0034s
#   CLAHE Processing: 0.0081s
#   Color Masking: 0.0038s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0124s
#   Line Detection & Draw: 0.0057s
#   Display Update: 0.0083s
# Total frame time: 0.1469s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0033s
#   CLAHE Processing: 0.0087s
#   Color Masking: 0.0025s
#   Color Morph: 0.0024s
#   Edge Detect & Morph: 0.0131s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0091s
# Total frame time: 0.1383s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0026s
#   CLAHE Processing: 0.0092s
#   Color Masking: 0.0037s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0103s
#   Line Detection & Draw: 0.0068s
#   Display Update: 0.0107s
# Total frame time: 0.1476s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0024s
#   CLAHE Processing: 0.0087s
#   Color Masking: 0.0036s
#   Color Morph: 0.0024s
#   Edge Detect & Morph: 0.0116s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0108s
# Total frame time: 0.1378s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0021s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0085s
#   Color Masking: 0.0039s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0127s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0124s
# Total frame time: 0.1488s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0023s
#   CLAHE Processing: 0.0085s
#   Color Masking: 0.0021s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0115s
#   Line Detection & Draw: 0.0062s
#   Display Update: 0.0084s
# Total frame time: 0.1466s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0092s
#   Color Masking: 0.0022s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0097s
#   Line Detection & Draw: 0.0079s
#   Display Update: 0.0102s
# Total frame time: 0.1494s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0020s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0096s
#   Color Masking: 0.0024s
#   Color Morph: 0.0031s
#   Edge Detect & Morph: 0.0096s
#   Line Detection & Draw: 0.0074s
#   Display Update: 0.0141s
# Total frame time: 0.1467s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0087s
#   Color Masking: 0.0034s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0109s
#   Line Detection & Draw: 0.0068s
#   Display Update: 0.0099s
# Total frame time: 0.1365s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0023s
#   CLAHE Processing: 0.0086s
#   Color Masking: 0.0021s
#   Color Morph: 0.0031s
#   Edge Detect & Morph: 0.0133s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0084s
# Total frame time: 0.1386s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0086s
#   Color Masking: 0.0037s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0095s
#   Line Detection & Draw: 0.0061s
#   Display Update: 0.0092s
# Total frame time: 0.1365s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0034s
#   CLAHE Processing: 0.0089s
#   Color Masking: 0.0027s
#   Color Morph: 0.0023s
#   Edge Detect & Morph: 0.0137s
#   Line Detection & Draw: 0.0068s
#   Display Update: 0.0085s
# Total frame time: 0.1373s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0032s
#   CLAHE Processing: 0.0081s
#   Color Masking: 0.0028s
#   Color Morph: 0.0033s
#   Edge Detect & Morph: 0.0110s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0117s
# Total frame time: 0.1466s
#
# Processing: 00421026.png (Index: 14)
#   Cropping: 0.0015s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0093s
#   Color Masking: 0.0027s
#   Color Morph: 0.0024s
#   Edge Detect & Morph: 0.0100s
#   Line Detection & Draw: 0.0070s
#   Display Update: 0.0103s
# Total frame time: 0.1398s
#
# Processing: 00421026.png (Index: 14)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0023s
#   CLAHE Processing: 0.0089s
#   Color Masking: 0.0039s
#   Color Morph: 0.0023s
#   Edge Detect & Morph: 0.0111s
#   Line Detection & Draw: 0.0070s
#   Display Update: 0.0117s
# Total frame time: 0.1538s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0090s
#   Color Masking: 0.0038s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0112s
#   Line Detection & Draw: 0.0057s
#   Display Update: 0.0089s
# Total frame time: 0.1340s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0014s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0087s
#   Color Masking: 0.0035s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0095s
#   Line Detection & Draw: 0.0071s
#   Display Update: 0.0100s
# Total frame time: 0.1532s
#
# Processing: 00421063.png (Index: 15)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0023s
#   CLAHE Processing: 0.0102s
#   Color Masking: 0.0022s
#   Color Morph: 0.0023s
#   Edge Detect & Morph: 0.0113s
#   Line Detection & Draw: 0.0068s
#   Display Update: 0.0112s
# Total frame time: 0.1477s
#
# Processing: 00421100.png (Index: 16)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0023s
#   CLAHE Processing: 0.0089s
#   Color Masking: 0.0037s
#   Color Morph: 0.0023s
#   Edge Detect & Morph: 0.0096s
#   Line Detection & Draw: 0.0068s
# ...
#   Color Masking: 0.0027s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0558s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0095s
# Total frame time: 0.1931s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0013s
#   CLAHE Processing: 0.0067s
#   Color Masking: 0.0025s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0443s
#   Line Detection & Draw: 0.0064s
#   Display Update: 0.0087s
# Total frame time: 0.1792s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0058s
#   Color Masking: 0.0023s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.0915s
#   Line Detection & Draw: 0.0057s
#   Display Update: 0.0076s
# Total frame time: 0.2263s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0053s
#   Color Masking: 0.0021s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.0451s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0090s
# Total frame time: 0.1803s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0027s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0442s
#   Line Detection & Draw: 0.0071s
#   Display Update: 0.0100s
# Total frame time: 0.1842s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0079s
#   Color Masking: 0.0025s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.1308s
#   Line Detection & Draw: 0.0091s
#   Display Update: 0.0188s
# Total frame time: 0.2931s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0034s
#   CLAHE Processing: 0.0102s
#   Color Masking: 0.0036s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0552s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0096s
# Total frame time: 0.2400s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0073s
#   Color Masking: 0.0023s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0619s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0077s
# Total frame time: 0.2067s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0079s
#   Color Masking: 0.0021s
#   Color Morph: 0.0024s
#   Edge Detect & Morph: 0.0471s
#   Line Detection & Draw: 0.0048s
#   Display Update: 0.0085s
# Total frame time: 0.1961s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0074s
#   Color Masking: 0.0021s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0454s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0091s
# Total frame time: 0.1928s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0075s
#   Color Masking: 0.0030s
#   Color Morph: 0.0015s
#   Edge Detect & Morph: 0.0653s
#   Line Detection & Draw: 0.0067s
#   Display Update: 0.0091s
# Total frame time: 0.2135s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0038s
#   CLAHE Processing: 0.0071s
#   Color Masking: 0.0027s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0552s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0091s
# Total frame time: 0.1920s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0063s
#   Color Masking: 0.0026s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0858s
#   Line Detection & Draw: 0.0070s
#   Display Update: 0.0133s
# Total frame time: 0.2338s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0061s
#   Color Masking: 0.0024s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0466s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0082s
# Total frame time: 0.1917s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0014s
#   CLAHE Processing: 0.0071s
#   Color Masking: 0.0010s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0437s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0082s
# Total frame time: 0.1894s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0070s
#   Color Masking: 0.0026s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0500s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0091s
# Total frame time: 0.1899s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0020s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0060s
#   Color Masking: 0.0030s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.1514s
#   Line Detection & Draw: 0.0053s
#   Display Update: 0.0173s
# Total frame time: 0.2903s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0070s
#   Color Masking: 0.0011s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0458s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0092s
# Total frame time: 0.1770s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0066s
#   Color Masking: 0.0026s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0439s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0075s
# Total frame time: 0.1813s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0066s
#   Color Masking: 0.0022s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0468s
#   Line Detection & Draw: 0.0045s
#   Display Update: 0.0079s
# Total frame time: 0.1833s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0061s
#   Color Masking: 0.0028s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0478s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0130s
# Total frame time: 0.1939s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0027s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0440s
#   Line Detection & Draw: 0.0045s
#   Display Update: 0.0092s
# Total frame time: 0.1878s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0014s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0065s
#   Color Masking: 0.0022s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0436s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0083s
# Total frame time: 0.1783s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0055s
#   Color Masking: 0.0026s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0456s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0121s
# Total frame time: 0.1786s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0069s
#   Color Masking: 0.0022s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0453s
#   Line Detection & Draw: 0.0050s
#   Display Update: 0.0096s
# Total frame time: 0.1912s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0063s
#   Color Masking: 0.0023s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.0438s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0113s
# Total frame time: 0.1889s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0069s
#   Color Masking: 0.0013s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0491s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0087s
# Total frame time: 0.1989s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0062s
#   Color Masking: 0.0035s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0461s
#   Line Detection & Draw: 0.0057s
#   Display Update: 0.0077s
# Total frame time: 0.1741s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0014s
#   CLAHE Processing: 0.0063s
#   Color Masking: 0.0029s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0448s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0079s
# Total frame time: 0.1800s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0057s
#   Color Masking: 0.0029s
#   Color Morph: 0.0025s
#   Edge Detect & Morph: 0.0442s
#   Line Detection & Draw: 0.0057s
#   Display Update: 0.0092s
# Total frame time: 0.1855s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0098s
#   Color Masking: 0.0048s
#   Color Morph: 0.0031s
#   Edge Detect & Morph: 0.0541s
#   Line Detection & Draw: 0.0053s
#   Display Update: 0.0091s
# Total frame time: 0.2361s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0058s
#   Color Masking: 0.0011s
#   Color Morph: 0.0027s
#   Edge Detect & Morph: 0.0458s
#   Line Detection & Draw: 0.0058s
#   Display Update: 0.0103s
# Total frame time: 0.1802s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0068s
#   Color Masking: 0.0035s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0824s
#   Line Detection & Draw: 0.0051s
#   Display Update: 0.0154s
# Total frame time: 0.2480s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0059s
#   Color Masking: 0.0027s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0549s
#   Line Detection & Draw: 0.0045s
#   Display Update: 0.0101s
# Total frame time: 0.2006s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0020s
#   CLAHE Processing: 0.0077s
#   Color Masking: 0.0022s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0625s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0088s
# Total frame time: 0.2284s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0012s
#   CLAHE Processing: 0.0067s
#   Color Masking: 0.0036s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.1496s
#   Line Detection & Draw: 0.0060s
#   Display Update: 0.0089s
# Total frame time: 0.3020s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0014s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0079s
#   Color Masking: 0.0032s
#   Color Morph: 0.0024s
#   Edge Detect & Morph: 0.1555s
#   Line Detection & Draw: 0.0068s
#   Display Update: 0.0080s
# Total frame time: 0.3354s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0025s
#   CLAHE Processing: 0.0076s
#   Color Masking: 0.0028s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.1029s
#   Line Detection & Draw: 0.0065s
#   Display Update: 0.0103s
# Total frame time: 0.2671s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0024s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0078s
#   Color Masking: 0.0020s
#   Color Morph: 0.0014s
#   Edge Detect & Morph: 0.0922s
#   Line Detection & Draw: 0.0056s
#   Display Update: 0.0107s
# Total frame time: 0.2652s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0024s
#   CLAHE Processing: 0.0067s
#   Color Masking: 0.0026s
#   Color Morph: 0.0024s
#   Edge Detect & Morph: 0.1401s
#   Line Detection & Draw: 0.0064s
#   Display Update: 0.0079s
# Total frame time: 0.3076s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0061s
#   Color Masking: 0.0027s
#   Color Morph: 0.0011s
#   Edge Detect & Morph: 0.0559s
#   Line Detection & Draw: 0.0060s
#   Display Update: 0.0106s
# Total frame time: 0.2118s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0000s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0032s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0468s
#   Line Detection & Draw: 0.0063s
#   Display Update: 0.0082s
# Total frame time: 0.1903s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0069s
#   Color Masking: 0.0034s
#   Color Morph: 0.0012s
#   Edge Detect & Morph: 0.0583s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0106s
# Total frame time: 0.2100s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0022s
#   CLAHE Processing: 0.0079s
#   Color Masking: 0.0015s
#   Color Morph: 0.0026s
#   Edge Detect & Morph: 0.0951s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0106s
# Total frame time: 0.2581s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0025s
#   CLAHE Processing: 0.0056s
#   Color Masking: 0.0028s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0661s
#   Line Detection & Draw: 0.0059s
#   Display Update: 0.0122s
# Total frame time: 0.2198s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0065s
#   Color Masking: 0.0022s
#   Color Morph: 0.0013s
#   Edge Detect & Morph: 0.0582s
#   Line Detection & Draw: 0.0055s
#   Display Update: 0.0092s
# Total frame time: 0.1978s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0014s
#   Pre-processing Resize: 0.0031s
#   CLAHE Processing: 0.0076s
#   Color Masking: 0.0031s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.0783s
#   Line Detection & Draw: 0.0052s
#   Display Update: 0.0098s
# Total frame time: 0.2273s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0074s
#   Color Masking: 0.0024s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0539s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0087s
# Total frame time: 0.2026s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0015s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0063s
#   Color Masking: 0.0014s
#   Color Morph: 0.0020s
#   Edge Detect & Morph: 0.0598s
#   Line Detection & Draw: 0.0044s
#   Display Update: 0.0075s
# Total frame time: 0.2117s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0061s
#   Color Masking: 0.0033s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0835s
#   Line Detection & Draw: 0.0054s
#   Display Update: 0.0086s
# Total frame time: 0.2128s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0011s
#   CLAHE Processing: 0.0100s
#   Color Masking: 0.0010s
#   Color Morph: 0.0025s
#   Edge Detect & Morph: 0.0906s
#   Line Detection & Draw: 0.0064s
#   Display Update: 0.0101s
# Total frame time: 0.2531s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0011s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0070s
#   Color Masking: 0.0021s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0639s
#   Line Detection & Draw: 0.0070s
#   Display Update: 0.0098s
# Total frame time: 0.2466s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0023s
#   Pre-processing Resize: 0.0021s
#   CLAHE Processing: 0.0064s
#   Color Masking: 0.0023s
#   Color Morph: 0.0010s
#   Edge Detect & Morph: 0.0521s
#   Line Detection & Draw: 0.0063s
#   Display Update: 0.0094s
# Total frame time: 0.2277s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0010s
#   Pre-processing Resize: 0.0010s
#   CLAHE Processing: 0.0067s
#   Color Masking: 0.0029s
#   Color Morph: 0.0022s
#   Edge Detect & Morph: 0.0531s
#   Line Detection & Draw: 0.0067s
#   Display Update: 0.0082s
# Total frame time: 0.2284s
#
# Processing: 00432396.png (Index: 297)
#   Cropping: 0.0012s
#   Pre-processing Resize: 0.0023s
#   CLAHE Processing: 0.0075s
#   Color Masking: 0.0024s
#   Color Morph: 0.0021s
#   Edge Detect & Morph: 0.0563s
#   Line Detection & Draw: 0.0045s
#   Display Update: 0.0108s
# Total frame time: 0.1945s
#
# Processing: 00432396.png (Index: 297)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 98
#      95 print(f"Processing: {filename} (Index: {current_index})")
#      97 filepath = os.path.join(image_folder, filename)
# ---> 98 image = cv2.imread(filepath)
#      99 if image is None:
#     100     print(f"❌ ERROR: Cannot read {filename}. Skipping to next image.")
#
# KeyboardInterrupt:
