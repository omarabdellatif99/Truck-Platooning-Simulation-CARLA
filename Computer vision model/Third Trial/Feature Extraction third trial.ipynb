# %%
import cv2
import numpy as np
import os
import math # For angle calculations
import pandas as pd # For CSV output

# --- Configuration: Hardcoded Parameters from Tuning ---
# IMPORTANT: Replace these values with the optimal parameters you found during tuning.
# Example values are provided, but your tuned values will be different.

# L*a*b* Color Space Ranges for Orange Line
LOWER_L_TUNED = 147
UPPER_L_TUNED = 221
LOWER_A_TUNED = 135
UPPER_A_TUNED = 157
LOWER_B_TUNED = 135
UPPER_B_TUNED = 161

# Morphological Kernel Size for Color Mask
COLOR_MORPH_KERNEL_SIZE_TUNED = 3

# Edge Pre-processing Filter (Bilateral or Gaussian)
USE_BILATERAL_FILTER_TUNED = 1 # 0 for Gaussian, 1 for Bilateral
BILATERAL_D_TUNED = 6
BILATERAL_SIGMA_COLOR_TUNED = 7
BILATERAL_SIGMA_SPACE_TUNED = 200

# Canny Edge Detector Thresholds
CANNY_THRESH1_TUNED = 3
CANNY_THRESH2_TUNED = 93

# Morphological Kernel Size for Edge Mask
EDGE_MORPH_KERNEL_SIZE_TUNED = 25

# Hough Line Transform Parameters
HOUGH_THRESHOLD_TUNED =15
HOUGH_MIN_LENGTH_TUNED =160
HOUGH_MAX_GAP_TUNED = 45

# Line Filtering Parameters (based on angle)
MAX_LINE_ANGLE_DEG_TUNED = 88 # Maximum allowed deviation from horizontal (0 or 180 degrees)

# Image Cropping Parameter
CROP_PERCENT_FROM_TOP_TUNED = 57 # Percentage of image height to crop from the top


# --- File Paths ---
# IMPORTANT: ADJUST THIS PATH to the folder containing your Carla environment images.
IMAGE_FOLDER = "C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data" 
OUTPUT_CSV_FILENAME = "lane_line_features_extracted.csv" # Name of the output CSV file


# --- Function to Process a Single Image and Extract Features ---
def extract_lane_line_features(image_path, params):
    """
    Processes a single image to detect the orange lane line and extract relevant features.

    Args:
        image_path (str): Full path to the image file.
        params (dict): Dictionary containing all the tuned parameters.

    Returns:
        dict: A dictionary of extracted features for the image.
              Returns default/NaN values if no line is detected or on error.
    """
    features = {
        "filename": os.path.basename(image_path),
        "is_line_detected": 0,
        "centroid_x_cropped": -1.0,
        "centroid_y_cropped": -1.0,
        "deviation_score": float('nan'), # Normalized deviation (-1 to 1)
        "num_line_segments": 0,
        "total_line_pixel_length": 0.0,
        "avg_line_angle_deg": 0.0,
        "std_line_angle_deg": 0.0,
        "min_line_y_cropped": -1.0, # Closest to top of cropped image
        "max_line_y_cropped": -1.0, # Closest to bottom of cropped image
        "fitted_line_slope_deg": 0.0,
        "fitted_line_x_intercept_at_bottom_cropped": -1.0,
        "fitted_line_x_intercept_at_top_cropped": -1.0,
    }

    image = cv2.imread(image_path)
    if image is None:
        print(f"❌ ERROR: Cannot read {image_path}. Skipping.")
        return features # Return default features

    original_h, original_w, _ = image.shape
    center_x_full_image = original_w // 2

    # --- 1. Crop from top ---
    crop_y = int(original_h * params["crop_percent_from_top"] / 100)
    if crop_y >= original_h:
        crop_y = original_h - 1
    cropped_image = image[crop_y:, :].copy()
    cropped_h, cropped_w, _ = cropped_image.shape

    # --- 2. Color Masking (L*a*b*) ---
    lab_cropped = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2LAB)
    l_channel, a_channel, b_channel = cv2.split(lab_cropped)
    
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
    l_eq = clahe.apply(l_channel)
    lab_eq = cv2.merge([l_eq, a_channel, b_channel])
    
    blurred_lab_eq = cv2.medianBlur(lab_eq, 5) 

    lower_orange_lab = np.array([params["lower_l"], params["lower_a"], params["lower_b"]])
    upper_orange_lab = np.array([params["upper_l"], params["upper_a"], params["upper_b"]])
    color_mask = cv2.inRange(blurred_lab_eq, lower_orange_lab, upper_orange_lab)

    # --- 3. Morphological Operations on Color Mask ---
    color_morph_kernel = np.ones((params["color_morph_kernel_size"], params["color_morph_kernel_size"]), np.uint8)
    color_mask_morphed = cv2.morphologyEx(color_mask, cv2.MORPH_OPEN, color_morph_kernel, iterations=1)
    color_mask_morphed = cv2.dilate(color_mask_morphed, color_morph_kernel, iterations=1) 
    color_mask_morphed = cv2.morphologyEx(color_mask_morphed, cv2.MORPH_CLOSE, color_morph_kernel, iterations=1)
    
    # --- 4. Edge Detection (Canny) ---
    gray_cropped = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2GRAY)
    
    if params["use_bilateral_filter"]:
        filtered_gray = cv2.bilateralFilter(gray_cropped, params["bilateral_d"], 
                                             params["bilateral_sigma_color"], params["bilateral_sigma_space"])
    else:
        filtered_gray = cv2.GaussianBlur(gray_cropped, (5, 5), 0)

    edge_mask = cv2.Canny(filtered_gray, params["canny_thresh1"], params["canny_thresh2"])

    edge_morph_kernel = np.ones((params["edge_morph_kernel_size"], params["edge_morph_kernel_size"]), np.uint8)
    edge_mask_morphed = cv2.morphologyEx(edge_mask, cv2.MORPH_CLOSE, edge_morph_kernel, iterations=1)

    # --- 5. Combine Color Mask and Morphed Edge Mask ---
    final_mask = cv2.bitwise_and(color_mask_morphed, edge_mask_morphed)

    # --- 6. Line Detection with Hough Transform ---
    lines = cv2.HoughLinesP(final_mask, 1, np.pi / 180, 
                            params["hough_threshold"], 
                            minLineLength=params["hough_min_length"], 
                            maxLineGap=params["hough_max_gap"])

    # --- 7. Filter Detected Lines and Calculate Features ---
    filtered_lines = []
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            angle_rad = math.atan2(y2 - y1, x2 - x1)
            angle_deg = math.degrees(angle_rad)

            if abs(angle_deg) < params["max_line_angle_deg"] or abs(angle_deg - 180) < params["max_line_angle_deg"]:
                filtered_lines.append(line[0]) # Store as flat list [x1, y1, x2, y2]

    if filtered_lines:
        features["is_line_detected"] = 1
        all_x_coords = []
        all_y_coords = []
        all_line_angles = []
        all_line_lengths = []

        for line_seg in filtered_lines:
            x1, y1, x2, y2 = line_seg
            all_x_coords.extend([x1, x2])
            all_y_coords.extend([y1, y2])

            angle_rad = math.atan2(y2 - y1, x2 - x1)
            all_line_angles.append(math.degrees(angle_rad))
            
            length = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
            all_line_lengths.append(length)
        
        # Calculate Centroid (mean of all segment points)
        features["centroid_x_cropped"] = np.mean(all_x_coords)
        features["centroid_y_cropped"] = np.mean(all_y_coords)

        # Deviation Score (normalized to full image center)
        # Convert centroid_x_cropped to full image x-coord first
        centroid_x_full_image_coord = features["centroid_x_cropped"] 
        if center_x_full_image != 0:
            features["deviation_score"] = (centroid_x_full_image_coord - center_x_full_image) / center_x_full_image
        else:
            features["deviation_score"] = 0.0 # Should not happen with valid images

        # Number of Line Segments
        features["num_line_segments"] = len(filtered_lines)

        # Total Line Pixel Length
        features["total_line_pixel_length"] = np.sum(all_line_lengths)

        # Average and Standard Deviation of Line Angles
        if all_line_angles:
            features["avg_line_angle_deg"] = np.mean(all_line_angles)
            if len(all_line_angles) > 1: # std dev requires at least 2 points
                features["std_line_angle_deg"] = np.std(all_line_angles)
            else:
                features["std_line_angle_deg"] = 0.0

        # Min and Max Y-coordinates (closest to top/bottom of cropped region)
        if all_y_coords:
            features["min_line_y_cropped"] = np.min(all_y_coords)
            features["max_line_y_cropped"] = np.max(all_y_coords)

        # Fitted Line Slope and Intercepts (y = mx + c)
        if len(all_x_coords) > 1 and len(np.unique(all_x_coords)) > 1: # Need at least 2 distinct X points for a slope
            try:
                slope, intercept = np.polyfit(all_x_coords, all_y_coords, 1)
                features["fitted_line_slope_deg"] = math.degrees(math.atan(slope))

                # Calculate x-intercepts at top and bottom of cropped image
                # y = mx + c  => x = (y - c) / m
                if slope != 0:
                    features["fitted_line_x_intercept_at_bottom_cropped"] = (cropped_h - 1 - intercept) / slope
                    features["fitted_line_x_intercept_at_top_cropped"] = (0 - intercept) / slope
                else: # Horizontal line, x-intercepts are undefined/at infinity for slope=0
                    features["fitted_line_x_intercept_at_bottom_cropped"] = features["centroid_x_cropped"]
                    features["fitted_line_x_intercept_at_top_cropped"] = features["centroid_x_cropped"]
            except np.linalg.LinAlgError:
                # This can happen if all points are vertically aligned (slope is infinite)
                # In such cases, the slope will be reported as 90 degrees or -90 degrees
                # and intercepts will be effectively the same x-coordinate.
                features["fitted_line_slope_deg"] = 90.0 if np.mean(all_y_coords) < cropped_h/2 else -90.0
                features["fitted_line_x_intercept_at_bottom_cropped"] = features["centroid_x_cropped"]
                features["fitted_line_x_intercept_at_top_cropped"] = features["centroid_x_cropped"]
            except Exception as e:
                print(f"Warning: Error fitting line for {image_path}: {e}")

    return features

# --- Main Execution Block ---
if __name__ == "__main__":
    print("--- Starting Lane Line Feature Extraction ---")

    # Collect image file paths
    image_files = [f for f in os.listdir(IMAGE_FOLDER) if f.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff"))]
    if not image_files:
        print(f"ERROR: No images found in '{IMAGE_FOLDER}'. Please check the path.")
        exit()

    print(f"Found {len(image_files)} images in '{IMAGE_FOLDER}'.")

    # Store all tuned parameters in a dictionary
    tuned_parameters = {
        "lower_l": LOWER_L_TUNED,
        "upper_l": UPPER_L_TUNED,
        "lower_a": LOWER_A_TUNED,
        "upper_a": UPPER_A_TUNED,
        "lower_b": LOWER_B_TUNED,
        "upper_b": UPPER_B_TUNED,
        "color_morph_kernel_size": COLOR_MORPH_KERNEL_SIZE_TUNED,
        "use_bilateral_filter": USE_BILATERAL_FILTER_TUNED,
        "bilateral_d": BILATERAL_D_TUNED,
        "bilateral_sigma_color": BILATERAL_SIGMA_COLOR_TUNED,
        "bilateral_sigma_space": BILATERAL_SIGMA_SPACE_TUNED,
        "canny_thresh1": CANNY_THRESH1_TUNED,
        "canny_thresh2": CANNY_THRESH2_TUNED,
        "edge_morph_kernel_size": EDGE_MORPH_KERNEL_SIZE_TUNED,
        "hough_threshold": HOUGH_THRESHOLD_TUNED,
        "hough_min_length": HOUGH_MIN_LENGTH_TUNED,
        "hough_max_gap": HOUGH_MAX_GAP_TUNED,
        "max_line_angle_deg": MAX_LINE_ANGLE_DEG_TUNED,
        "crop_percent_from_top": CROP_PERCENT_FROM_TOP_TUNED,
    }

    all_extracted_features = []
    
    for i, filename in enumerate(image_files):
        full_image_path = os.path.join(IMAGE_FOLDER, filename)
        print(f"Processing image {i+1}/{len(image_files)}: {filename}")
        
        features = extract_lane_line_features(full_image_path, tuned_parameters)
        all_extracted_features.append(features)

    # Create a pandas DataFrame from the collected features
    df = pd.DataFrame(all_extracted_features)

    # Save the DataFrame to a CSV file
    output_csv_path = os.path.join(os.path.dirname(IMAGE_FOLDER), OUTPUT_CSV_FILENAME)
    df.to_csv(output_csv_path, index=False)

    print(f"\n✅ Feature extraction complete! Data saved to: {output_csv_path}")
# Out:
# --- Starting Lane Line Feature Extraction ---
# Found 1291 images in 'C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data'.
# Processing image 1/1291: 00420478.png
# Processing image 2/1291: 00420523.png
# Processing image 3/1291: 00420564.png
# Processing image 4/1291: 00420604.png
# Processing image 5/1291: 00420644.png
# Processing image 6/1291: 00420684.png
# Processing image 7/1291: 00420725.png
# Processing image 8/1291: 00420765.png
# Processing image 9/1291: 00420803.png
# Processing image 10/1291: 00420841.png
# Processing image 11/1291: 00420878.png
# Processing image 12/1291: 00420915.png
# Processing image 13/1291: 00420952.png
# Processing image 14/1291: 00420989.png
# Processing image 15/1291: 00421026.png
# Processing image 16/1291: 00421063.png
# Processing image 17/1291: 00421100.png
# Processing image 18/1291: 00421137.png
# Processing image 19/1291: 00421175.png
# Processing image 20/1291: 00421214.png
# Processing image 21/1291: 00421255.png
# Processing image 22/1291: 00421296.png
# Processing image 23/1291: 00421337.png
# Processing image 24/1291: 00421379.png
# Processing image 25/1291: 00421420.png
# Processing image 26/1291: 00421461.png
# Processing image 27/1291: 00421502.png
# Processing image 28/1291: 00421543.png
# Processing image 29/1291: 00421584.png
# Processing image 30/1291: 00421625.png
# Processing image 31/1291: 00421666.png
# Processing image 32/1291: 00421707.png
# Processing image 33/1291: 00421748.png
# Processing image 34/1291: 00421789.png
# Processing image 35/1291: 00421830.png
# Processing image 36/1291: 00421871.png
# Processing image 37/1291: 00421912.png
# Processing image 38/1291: 00421953.png
# Processing image 39/1291: 00421994.png
# Processing image 40/1291: 00422034.png
# Processing image 41/1291: 00422073.png
# Processing image 42/1291: 00422112.png
# Processing image 43/1291: 00422150.png
# Processing image 44/1291: 00422187.png
# Processing image 45/1291: 00422224.png
# Processing image 46/1291: 00422261.png
# Processing image 47/1291: 00422297.png
# Processing image 48/1291: 00422334.png
# Processing image 49/1291: 00422371.png
# Processing image 50/1291: 00422408.png
# Processing image 51/1291: 00422445.png
# Processing image 52/1291: 00422482.png
# Processing image 799/1291: 00452415.png
# Processing image 800/1291: 00452456.png
# Processing image 801/1291: 00452497.png
# Processing image 802/1291: 00452538.png
# Processing image 803/1291: 00452579.png
# Processing image 804/1291: 00452619.png
# Processing image 805/1291: 00452660.png
# Processing image 806/1291: 00452700.png
# Processing image 807/1291: 00452739.png
# Processing image 808/1291: 00452778.png
# Processing image 809/1291: 00452818.png
# Processing image 810/1291: 00452859.png
# Processing image 811/1291: 00452900.png
# Processing image 812/1291: 00452941.png
# Processing image 813/1291: 00452981.png
# Processing image 814/1291: 00453022.png
# Processing image 815/1291: 00453060.png
# Processing image 816/1291: 00453097.png
# Processing image 817/1291: 00453135.png
# Processing image 818/1291: 00453174.png
# Processing image 819/1291: 00453214.png
# Processing image 820/1291: 00453255.png
# Processing image 821/1291: 00453296.png
# Processing image 822/1291: 00453337.png
# Processing image 823/1291: 00453378.png
# Processing image 824/1291: 00453419.png
# Processing image 825/1291: 00453459.png
# Processing image 826/1291: 00453497.png
# Processing image 827/1291: 00453534.png
# Processing image 828/1291: 00453570.png
# Processing image 829/1291: 00453606.png
# Processing image 830/1291: 00453642.png
# Processing image 831/1291: 00453679.png
# Processing image 832/1291: 00453716.png
# Processing image 833/1291: 00453754.png
# Processing image 834/1291: 00453791.png
# Processing image 835/1291: 00453829.png
# Processing image 836/1291: 00453868.png
# Processing image 837/1291: 00453909.png
# Processing image 838/1291: 00453950.png
# Processing image 839/1291: 00453992.png
# Processing image 840/1291: 00454033.png
# Processing image 841/1291: 00454074.png
# Processing image 842/1291: 00454114.png
# Processing image 843/1291: 00454155.png
# Processing image 844/1291: 00454196.png
# Processing image 845/1291: 00454236.png
# Processing image 846/1291: 00454274.png
# Processing image 847/1291: 00454312.png
# Processing image 848/1291: 00454350.png
# Processing image 849/1291: 00454390.png
# Processing image 850/1291: 00454430.png
# Processing image 851/1291: 00454471.png
# Processing image 852/1291: 00454512.png
# Processing image 853/1291: 00454553.png
# Processing image 854/1291: 00454594.png
# Processing image 855/1291: 00454635.png
# Processing image 856/1291: 00454675.png
# Processing image 857/1291: 00454715.png
# Processing image 858/1291: 00454755.png
# Processing image 859/1291: 00454795.png
# Processing image 860/1291: 00454833.png
# Processing image 861/1291: 00454870.png
# Processing image 862/1291: 00454906.png
# Processing image 863/1291: 00454942.png
# Processing image 864/1291: 00454978.png
# Processing image 865/1291: 00455016.png
# Processing image 866/1291: 00455055.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455055.png. Skipping.
# Processing image 867/1291: 00455096.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455096.png. Skipping.
# Processing image 868/1291: 00455137.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455137.png. Skipping.
# Processing image 869/1291: 00455178.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455178.png. Skipping.
# Processing image 870/1291: 00455219.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455219.png. Skipping.
# Processing image 871/1291: 00455259.png
# Processing image 872/1291: 00455300.png
# Processing image 873/1291: 00455339.png
# Processing image 874/1291: 00455376.png
# Processing image 875/1291: 00455415.png
# Processing image 876/1291: 00455454.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455454.png. Skipping.
# Processing image 877/1291: 00455495.png
# Processing image 878/1291: 00455535.png
# Processing image 879/1291: 00455576.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455576.png. Skipping.
# Processing image 880/1291: 00455616.png
# Processing image 881/1291: 00455656.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455656.png. Skipping.
# Processing image 882/1291: 00455697.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455697.png. Skipping.
# Processing image 883/1291: 00455737.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455737.png. Skipping.
# Processing image 884/1291: 00455776.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455776.png. Skipping.
# Processing image 885/1291: 00455816.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455816.png. Skipping.
# Processing image 886/1291: 00455856.png
# Processing image 887/1291: 00455897.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455897.png. Skipping.
# Processing image 888/1291: 00455938.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00455938.png. Skipping.
# Processing image 889/1291: 00455979.png
# Processing image 890/1291: 00456020.png
# Processing image 891/1291: 00456061.png
# Processing image 892/1291: 00456102.png
# Processing image 893/1291: 00456143.png
# Processing image 894/1291: 00456184.png
# Processing image 895/1291: 00456224.png
# Processing image 896/1291: 00456265.png
# Processing image 897/1291: 00456306.png
# Processing image 898/1291: 00456344.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456344.png. Skipping.
# Processing image 899/1291: 00456382.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456382.png. Skipping.
# Processing image 900/1291: 00456420.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456420.png. Skipping.
# Processing image 901/1291: 00456458.png
# Processing image 902/1291: 00456497.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456497.png. Skipping.
# Processing image 903/1291: 00456536.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456536.png. Skipping.
# Processing image 904/1291: 00456575.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456575.png. Skipping.
# Processing image 905/1291: 00456613.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456613.png. Skipping.
# Processing image 906/1291: 00456653.png
# Processing image 907/1291: 00456694.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456694.png. Skipping.
# Processing image 908/1291: 00456734.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456734.png. Skipping.
# Processing image 909/1291: 00456774.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456774.png. Skipping.
# Processing image 910/1291: 00456814.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456814.png. Skipping.
# Processing image 911/1291: 00456854.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456854.png. Skipping.
# Processing image 912/1291: 00456894.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456894.png. Skipping.
# Processing image 913/1291: 00456935.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456935.png. Skipping.
# Processing image 914/1291: 00456976.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00456976.png. Skipping.
# Processing image 915/1291: 00457016.png
# Processing image 916/1291: 00457057.png
# Processing image 917/1291: 00457097.png
# Processing image 918/1291: 00457138.png
# Processing image 919/1291: 00457179.png
# Processing image 920/1291: 00457219.png
# Processing image 921/1291: 00457259.png
# Processing image 922/1291: 00457299.png
# Processing image 923/1291: 00457339.png
# Processing image 924/1291: 00457378.png
# Processing image 925/1291: 00457417.png
# Processing image 926/1291: 00457456.png
# Processing image 927/1291: 00457494.png
# Processing image 928/1291: 00457533.png
# Processing image 929/1291: 00457572.png
# Processing image 930/1291: 00457611.png
# Processing image 931/1291: 00457650.png
# Processing image 932/1291: 00457689.png
# Processing image 933/1291: 00457729.png
# Processing image 934/1291: 00457770.png
# Processing image 935/1291: 00457811.png
# Processing image 936/1291: 00457852.png
# Processing image 937/1291: 00457893.png
# Processing image 938/1291: 00457934.png
# Processing image 939/1291: 00457975.png
# Processing image 940/1291: 00458015.png
# Processing image 941/1291: 00458055.png
# Processing image 942/1291: 00458094.png
# Processing image 943/1291: 00458132.png
# Processing image 944/1291: 00458170.png
# Processing image 945/1291: 00458208.png
# Processing image 946/1291: 00458247.png
# Processing image 947/1291: 00458286.png
# Processing image 948/1291: 00458326.png
# Processing image 949/1291: 00458366.png
# Processing image 950/1291: 00458407.png
# Processing image 951/1291: 00458447.png
# Processing image 952/1291: 00458486.png
# Processing image 953/1291: 00458525.png
# Processing image 954/1291: 00458566.png
# Processing image 955/1291: 00458607.png
# Processing image 956/1291: 00458649.png
# Processing image 957/1291: 00458690.png
# Processing image 958/1291: 00458731.png
# Processing image 959/1291: 00458772.png
# Processing image 960/1291: 00458813.png
# Processing image 961/1291: 00458853.png
# Processing image 962/1291: 00458893.png
# Processing image 963/1291: 00458932.png
# Processing image 964/1291: 00458970.png
# Processing image 965/1291: 00459010.png
# Processing image 966/1291: 00459051.png
# Processing image 967/1291: 00459092.png
# Processing image 968/1291: 00459133.png
# Processing image 969/1291: 00459174.png
# Processing image 970/1291: 00459215.png
# Processing image 971/1291: 00459256.png
# Processing image 972/1291: 00459297.png
# Processing image 973/1291: 00459338.png
# Processing image 974/1291: 00459379.png
# Processing image 975/1291: 00459419.png
# Processing image 976/1291: 00459459.png
# Processing image 977/1291: 00459499.png
# Processing image 978/1291: 00459540.png
# Processing image 979/1291: 00459581.png
# Processing image 980/1291: 00459621.png
# Processing image 981/1291: 00459661.png
# Processing image 982/1291: 00459702.png
# Processing image 983/1291: 00459742.png
# Processing image 984/1291: 00459782.png
# Processing image 985/1291: 00459822.png
# Processing image 986/1291: 00459861.png
# Processing image 987/1291: 00459900.png
# Processing image 988/1291: 00459938.png
# Processing image 989/1291: 00459978.png
# Processing image 990/1291: 00460019.png
# Processing image 991/1291: 00460060.png
# Processing image 992/1291: 00460101.png
# Processing image 993/1291: 00460142.png
# Processing image 994/1291: 00460183.png
# Processing image 995/1291: 00460224.png
# Processing image 996/1291: 00460265.png
# Processing image 997/1291: 00460306.png
# Processing image 998/1291: 00460347.png
# Processing image 999/1291: 00460388.png
# Processing image 1000/1291: 00460427.png
# Processing image 1001/1291: 00460466.png
# Processing image 1002/1291: 00460504.png
# Processing image 1003/1291: 00460540.png
# Processing image 1004/1291: 00460576.png
# Processing image 1005/1291: 00460613.png
# Processing image 1006/1291: 00460650.png
# Processing image 1007/1291: 00460687.png
# Processing image 1008/1291: 00460726.png
# Processing image 1009/1291: 00460764.png
# Processing image 1010/1291: 00460799.png
# Processing image 1011/1291: 00460834.png
# Processing image 1012/1291: 00460869.png
# Processing image 1013/1291: 00460903.png
# Processing image 1014/1291: 00460938.png
# Processing image 1015/1291: 00460975.png
# Processing image 1016/1291: 00461011.png
# Processing image 1017/1291: 00461049.png
# Processing image 1018/1291: 00461087.png
# Processing image 1019/1291: 00461127.png
# Processing image 1020/1291: 00461168.png
# Processing image 1021/1291: 00461208.png
# Processing image 1022/1291: 00461249.png
# Processing image 1023/1291: 00461290.png
# Processing image 1024/1291: 00461331.png
# ...
# Processing image 1078/1291: 00463484.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00463484.png. Skipping.
# Processing image 1079/1291: 00463522.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00463522.png. Skipping.
# Processing image 1080/1291: 00463561.png
# Processing image 1081/1291: 00463602.png
# Processing image 1082/1291: 00463642.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00463642.png. Skipping.
# Processing image 1083/1291: 00463683.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00463683.png. Skipping.
# Processing image 1084/1291: 00463724.png
# Processing image 1085/1291: 00463764.png
# Processing image 1086/1291: 00463802.png
# Processing image 1087/1291: 00463841.png
# Processing image 1088/1291: 00463878.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00463878.png. Skipping.
# Processing image 1089/1291: 00463919.png
# Processing image 1090/1291: 00463960.png
# Processing image 1091/1291: 00464001.png
# Processing image 1092/1291: 00464042.png
# Processing image 1093/1291: 00464084.png
# Processing image 1094/1291: 00464125.png
# Processing image 1095/1291: 00464166.png
# Processing image 1096/1291: 00464207.png
# Processing image 1097/1291: 00464248.png
# Processing image 1098/1291: 00464289.png
# Processing image 1099/1291: 00464330.png
# Processing image 1100/1291: 00464370.png
# Processing image 1101/1291: 00464409.png
# Processing image 1102/1291: 00464446.png
# Processing image 1103/1291: 00464483.png
# Processing image 1104/1291: 00464519.png
# Processing image 1105/1291: 00464556.png
# Processing image 1106/1291: 00464593.png
# Processing image 1107/1291: 00464630.png
# Processing image 1108/1291: 00464667.png
# Processing image 1109/1291: 00464702.png
# Processing image 1110/1291: 00464737.png
# Processing image 1111/1291: 00464772.png
# Processing image 1112/1291: 00464807.png
# Processing image 1113/1291: 00464845.png
# Processing image 1114/1291: 00464885.png
# Processing image 1115/1291: 00464925.png
# Processing image 1116/1291: 00464965.png
# Processing image 1117/1291: 00465006.png
# Processing image 1118/1291: 00465047.png
# Processing image 1119/1291: 00465088.png
# Processing image 1120/1291: 00465129.png
# Processing image 1121/1291: 00465170.png
# Processing image 1122/1291: 00465211.png
# Processing image 1123/1291: 00465252.png
# Processing image 1124/1291: 00465292.png
# Processing image 1125/1291: 00465332.png
# Processing image 1126/1291: 00465372.png
# Processing image 1127/1291: 00465413.png
# Processing image 1128/1291: 00465454.png
# Processing image 1129/1291: 00465495.png
# Processing image 1130/1291: 00465536.png
# Processing image 1131/1291: 00465577.png
# Processing image 1132/1291: 00465618.png
# Processing image 1133/1291: 00465659.png
# Processing image 1134/1291: 00465699.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00465699.png. Skipping.
# Processing image 1135/1291: 00465737.png
# Processing image 1136/1291: 00465774.png
# Processing image 1137/1291: 00465811.png
# Processing image 1138/1291: 00465852.png
# Processing image 1139/1291: 00465892.png
# Processing image 1140/1291: 00465932.png
# Processing image 1141/1291: 00465973.png
# Processing image 1142/1291: 00466014.png
# Processing image 1143/1291: 00466055.png
# Processing image 1144/1291: 00466095.png
# Processing image 1145/1291: 00466135.png
# Processing image 1146/1291: 00466174.png
# Processing image 1147/1291: 00466212.png
# Processing image 1148/1291: 00466250.png
# Processing image 1149/1291: 00466291.png
# Processing image 1150/1291: 00466332.png
# Processing image 1151/1291: 00466372.png
# Processing image 1152/1291: 00466413.png
# Processing image 1153/1291: 00466454.png
# Processing image 1154/1291: 00466495.png
# Processing image 1155/1291: 00466535.png
# Processing image 1156/1291: 00466576.png
# Processing image 1157/1291: 00466617.png
# Processing image 1158/1291: 00466657.png
# Processing image 1159/1291: 00466698.png
# Processing image 1160/1291: 00466739.png
# Processing image 1161/1291: 00466780.png
# Processing image 1162/1291: 00466820.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00466820.png. Skipping.
# Processing image 1163/1291: 00466859.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00466859.png. Skipping.
# Processing image 1164/1291: 00466898.png
# Processing image 1165/1291: 00466938.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00466938.png. Skipping.
# Processing image 1166/1291: 00466979.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00466979.png. Skipping.
# Processing image 1167/1291: 00467020.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467020.png. Skipping.
# Processing image 1168/1291: 00467060.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467060.png. Skipping.
# Processing image 1169/1291: 00467100.png
# Processing image 1170/1291: 00467141.png
# Processing image 1171/1291: 00467182.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467182.png. Skipping.
# Processing image 1172/1291: 00467222.png
# Processing image 1173/1291: 00467262.png
# Processing image 1174/1291: 00467301.png
# Processing image 1175/1291: 00467340.png
# Processing image 1176/1291: 00467379.png
# Processing image 1177/1291: 00467418.png
# Processing image 1178/1291: 00467456.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467456.png. Skipping.
# Processing image 1179/1291: 00467494.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467494.png. Skipping.
# Processing image 1180/1291: 00467534.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467534.png. Skipping.
# Processing image 1181/1291: 00467575.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467575.png. Skipping.
# Processing image 1182/1291: 00467616.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467616.png. Skipping.
# Processing image 1183/1291: 00467656.png
# Processing image 1184/1291: 00467697.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467697.png. Skipping.
# Processing image 1185/1291: 00467738.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467738.png. Skipping.
# Processing image 1186/1291: 00467778.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467778.png. Skipping.
# Processing image 1187/1291: 00467818.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467818.png. Skipping.
# Processing image 1188/1291: 00467859.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467859.png. Skipping.
# Processing image 1189/1291: 00467900.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467900.png. Skipping.
# Processing image 1190/1291: 00467941.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467941.png. Skipping.
# Processing image 1191/1291: 00467982.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00467982.png. Skipping.
# Processing image 1192/1291: 00468022.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468022.png. Skipping.
# Processing image 1193/1291: 00468062.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468062.png. Skipping.
# Processing image 1194/1291: 00468102.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468102.png. Skipping.
# Processing image 1195/1291: 00468141.png
# Processing image 1196/1291: 00468182.png
# Processing image 1197/1291: 00468222.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468222.png. Skipping.
# Processing image 1198/1291: 00468263.png
# Processing image 1199/1291: 00468303.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468303.png. Skipping.
# Processing image 1200/1291: 00468343.png
# Processing image 1201/1291: 00468384.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468384.png. Skipping.
# Processing image 1202/1291: 00468425.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468425.png. Skipping.
# Processing image 1203/1291: 00468465.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468465.png. Skipping.
# Processing image 1204/1291: 00468505.png
# Processing image 1205/1291: 00468545.png
# Processing image 1206/1291: 00468586.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468586.png. Skipping.
# Processing image 1207/1291: 00468626.png
# Processing image 1208/1291: 00468666.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468666.png. Skipping.
# Processing image 1209/1291: 00468706.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468706.png. Skipping.
# Processing image 1210/1291: 00468745.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468745.png. Skipping.
# Processing image 1211/1291: 00468783.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468783.png. Skipping.
# Processing image 1212/1291: 00468821.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468821.png. Skipping.
# Processing image 1213/1291: 00468859.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468859.png. Skipping.
# Processing image 1214/1291: 00468899.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468899.png. Skipping.
# Processing image 1215/1291: 00468940.png
# Processing image 1216/1291: 00468981.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00468981.png. Skipping.
# Processing image 1217/1291: 00469022.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469022.png. Skipping.
# Processing image 1218/1291: 00469063.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469063.png. Skipping.
# Processing image 1219/1291: 00469104.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469104.png. Skipping.
# Processing image 1220/1291: 00469145.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469145.png. Skipping.
# Processing image 1221/1291: 00469185.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469185.png. Skipping.
# Processing image 1222/1291: 00469226.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469226.png. Skipping.
# Processing image 1223/1291: 00469267.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469267.png. Skipping.
# Processing image 1224/1291: 00469308.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469308.png. Skipping.
# Processing image 1225/1291: 00469349.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469349.png. Skipping.
# Processing image 1226/1291: 00469389.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469389.png. Skipping.
# Processing image 1227/1291: 00469429.png
# Processing image 1228/1291: 00469469.png
# Processing image 1229/1291: 00469509.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469509.png. Skipping.
# Processing image 1230/1291: 00469548.png
# Processing image 1231/1291: 00469589.png
# Processing image 1232/1291: 00469629.png
# Processing image 1233/1291: 00469669.png
# Processing image 1234/1291: 00469709.png
# Processing image 1235/1291: 00469749.png
# Processing image 1236/1291: 00469790.png
# Processing image 1237/1291: 00469831.png
# Processing image 1238/1291: 00469872.png
# Processing image 1239/1291: 00469912.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469912.png. Skipping.
# Processing image 1240/1291: 00469952.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00469952.png. Skipping.
# Processing image 1241/1291: 00469991.png
# Processing image 1242/1291: 00470029.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470029.png. Skipping.
# Processing image 1243/1291: 00470068.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470068.png. Skipping.
# Processing image 1244/1291: 00470106.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470106.png. Skipping.
# Processing image 1245/1291: 00470144.png
# Processing image 1246/1291: 00470182.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470182.png. Skipping.
# Processing image 1247/1291: 00470220.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470220.png. Skipping.
# Processing image 1248/1291: 00470258.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470258.png. Skipping.
# Processing image 1249/1291: 00470296.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470296.png. Skipping.
# Processing image 1250/1291: 00470334.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470334.png. Skipping.
# Processing image 1251/1291: 00470374.png
# ❌ ERROR: Cannot read C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset/good_data\00470374.png. Skipping.
# Processing image 1252/1291: 00470415.png
# Processing image 1253/1291: 00470455.png
# Processing image 1254/1291: 00470495.png
# Processing image 1255/1291: 00470534.png
# Processing image 1256/1291: 00470575.png
# Processing image 1257/1291: 00470616.png
# Processing image 1258/1291: 00470657.png
# Processing image 1259/1291: 00470697.png
# Processing image 1260/1291: 00470738.png
# Processing image 1261/1291: 00470779.png
# Processing image 1262/1291: 00470819.png
# Processing image 1263/1291: 00470859.png
# Processing image 1264/1291: 00470898.png
# Processing image 1265/1291: 00470936.png
# Processing image 1266/1291: 00470976.png
# Processing image 1267/1291: 00471016.png
# Processing image 1268/1291: 00471057.png
# Processing image 1269/1291: 00471098.png
# Processing image 1270/1291: 00471137.png
# Processing image 1271/1291: 00471178.png
# Processing image 1272/1291: 00471218.png
# Processing image 1273/1291: 00471259.png
# Processing image 1274/1291: 00471300.png
# Processing image 1275/1291: 00471341.png
# Processing image 1276/1291: 00471381.png
# Processing image 1277/1291: 00471420.png
# Processing image 1278/1291: 00471460.png
# Processing image 1279/1291: 00471498.png
# Processing image 1280/1291: 00471538.png
# Processing image 1281/1291: 00471577.png
# Processing image 1282/1291: 00471616.png
# Processing image 1283/1291: 00471655.png
# Processing image 1284/1291: 00471694.png
# Processing image 1285/1291: 00471733.png
# Processing image 1286/1291: 00471772.png
# Processing image 1287/1291: 00471811.png
# Processing image 1288/1291: 00471852.png
# Processing image 1289/1291: 00471891.png
# Processing image 1290/1291: 00471931.png
# Processing image 1291/1291: 00471970.png
#
# ✅ Feature extraction complete! Data saved to: C:/Users/BCI-Lab/Downloads/teamA_dataset/_out_dataset\lane_line_features_extracted.csv
